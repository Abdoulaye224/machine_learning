# %%
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import gc
import lightgbm as lgb
import joblib
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# %%
calendar = pd.read_csv("data/calendar.csv")
train_eva = pd.read_csv("data/sales_train_evaluation.csv")
sell_prices = pd.read_csv("data/sell_prices.csv")
sample_sub = pd.read_csv("data/sample_submission.csv")

# %%
years = range(1942, 1970)
train_eva_cols = ['d_' + str(d) for d in years]
train_eva[train_eva_cols] = np.zeros((len(train_eva), len(train_eva_cols)), dtype=np.int16)

# %%
def downcast(df):
    df = df.copy()
    dtypes = df.dtypes

    for col in df.columns:
        if 'int' in str(dtypes[col]):
            df[col] = pd.to_numeric(df[col], downcast='integer')
        elif 'float' in str(dtypes[col]):
            df[col] = pd.to_numeric(df[col], downcast='float')
        elif dtypes[col] == np.object:
            if col == 'date':
                df[col] = pd.to_datetime(df[col], format='%Y-%m-%d')
            else:
                df[col] = df[col].astype('category')

    return df

# %%
train_eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1975 entries, id to d_1969
# dtypes: int64(1969), object(6)
# memory usage: 459.4+ MB

# %%
print("Downcasting data")
train_eva = downcast(train_eva)
sell_prices = downcast(sell_prices)
calendar = downcast(calendar)
# Out:
# Downcasting data
# CPU times: total: 3min 33s
# Wall time: 3min 37s

# %%
train_eva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1975 entries, id to d_1969
# dtypes: category(6), int16(1299), int8(670)
# memory usage: 96.6 MB

# %%
print("Melting data")
df = pd.melt(frame=train_eva, 
             id_vars=["id", "item_id", "dept_id", "cat_id", "store_id", "state_id"],
             var_name="d", value_name="sold")
# Out:
# Melting data

# %%
print("Merging data")
df = pd.merge(left=df, right=calendar, how="left", on="d")
df = pd.merge(left=df, right=sell_prices, on=["store_id", "item_id", "wm_yr_wk"], how="left")
# Out:
# Merging data
# CPU times: total: 51.7 s
# Wall time: 54.6 s

# %%
df["snap"] = (df["snap_CA"] + df["snap_TX"] + df["snap_WI"]).apply(lambda x: 1 if x >= 1 else 0).astype(np.int8)

df["d"] = df["d"].str[2:].astype(np.int16)

df["sell_price"] = df.groupby('id')['sell_price'].transform(lambda x: x.fillna(x.median()))

df["weekend"] = np.where(df["wday"] < 3, 1, 0).astype(np.int8)
df = df.drop(["date", "weekday", "wm_yr_wk", "event_name_2", "event_type_2", "snap_CA", "snap_TX", "snap_WI"], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

d_id = dict(zip(df["id"].cat.codes, df["id"]))

df["id"] = label_encoder.fit_transform(df["id"])
df["item_id"] = label_encoder.fit_transform(df["item_id"])
df["dept_id"] = label_encoder.fit_transform(df["dept_id"])
df["cat_id"] = label_encoder.fit_transform(df["cat_id"])
df["store_id"] = label_encoder.fit_transform(df["store_id"])
df["state_id"] = label_encoder.fit_transform(df["state_id"])
df["event_name_1"] = label_encoder.fit_transform(df["event_name_1"])
df["event_type_1"] = label_encoder.fit_transform(df["event_type_1"])

# %%
d_id
# Out:
# {14370: 'HOBBIES_1_001_CA_1_evaluation',
#  14380: 'HOBBIES_1_002_CA_1_evaluation',
#  14390: 'HOBBIES_1_003_CA_1_evaluation',
#  14400: 'HOBBIES_1_004_CA_1_evaluation',
#  14410: 'HOBBIES_1_005_CA_1_evaluation',
#  14420: 'HOBBIES_1_006_CA_1_evaluation',
#  14430: 'HOBBIES_1_007_CA_1_evaluation',
#  14440: 'HOBBIES_1_008_CA_1_evaluation',
#  14450: 'HOBBIES_1_009_CA_1_evaluation',
#  14460: 'HOBBIES_1_010_CA_1_evaluation',
#  14470: 'HOBBIES_1_011_CA_1_evaluation',
#  14480: 'HOBBIES_1_012_CA_1_evaluation',
#  14490: 'HOBBIES_1_013_CA_1_evaluation',
#  14500: 'HOBBIES_1_014_CA_1_evaluation',
#  14510: 'HOBBIES_1_015_CA_1_evaluation',
#  14520: 'HOBBIES_1_016_CA_1_evaluation',
#  14530: 'HOBBIES_1_017_CA_1_evaluation',
#  14540: 'HOBBIES_1_018_CA_1_evaluation',
#  14550: 'HOBBIES_1_019_CA_1_evaluation',
#  14560: 'HOBBIES_1_020_CA_1_evaluation',
#  14570: 'HOBBIES_1_021_CA_1_evaluation',
#  14580: 'HOBBIES_1_022_CA_1_evaluation',
#  14590: 'HOBBIES_1_023_CA_1_evaluation',
#  14600: 'HOBBIES_1_024_CA_1_evaluation',
#  14610: 'HOBBIES_1_025_CA_1_evaluation',
#  14620: 'HOBBIES_1_026_CA_1_evaluation',
#  14630: 'HOBBIES_1_027_CA_1_evaluation',
#  14640: 'HOBBIES_1_028_CA_1_evaluation',
#  14650: 'HOBBIES_1_029_CA_1_evaluation',
#  14660: 'HOBBIES_1_030_CA_1_evaluation',
#  14670: 'HOBBIES_1_031_CA_1_evaluation',
#  14680: 'HOBBIES_1_032_CA_1_evaluation',
#  14690: 'HOBBIES_1_033_CA_1_evaluation',
#  14700: 'HOBBIES_1_034_CA_1_evaluation',
#  14710: 'HOBBIES_1_035_CA_1_evaluation',
#  14720: 'HOBBIES_1_036_CA_1_evaluation',
#  14730: 'HOBBIES_1_037_CA_1_evaluation',
#  14740: 'HOBBIES_1_038_CA_1_evaluation',
#  14750: 'HOBBIES_1_039_CA_1_evaluation',
#  14760: 'HOBBIES_1_040_CA_1_evaluation',
#  14770: 'HOBBIES_1_041_CA_1_evaluation',
#  14780: 'HOBBIES_1_042_CA_1_evaluation',
#  14790: 'HOBBIES_1_043_CA_1_evaluation',
#  14800: 'HOBBIES_1_044_CA_1_evaluation',
#  14810: 'HOBBIES_1_045_CA_1_evaluation',
#  14820: 'HOBBIES_1_046_CA_1_evaluation',
#  14830: 'HOBBIES_1_047_CA_1_evaluation',
#  14840: 'HOBBIES_1_048_CA_1_evaluation',
#  14850: 'HOBBIES_1_049_CA_1_evaluation',
#  14860: 'HOBBIES_1_050_CA_1_evaluation',
#  14870: 'HOBBIES_1_051_CA_1_evaluation',
#  14880: 'HOBBIES_1_052_CA_1_evaluation',
#  14890: 'HOBBIES_1_053_CA_1_evaluation',
#  14900: 'HOBBIES_1_054_CA_1_evaluation',
#  14910: 'HOBBIES_1_055_CA_1_evaluation',
#  14920: 'HOBBIES_1_056_CA_1_evaluation',
#  14930: 'HOBBIES_1_057_CA_1_evaluation',
#  14940: 'HOBBIES_1_058_CA_1_evaluation',
#  14950: 'HOBBIES_1_060_CA_1_evaluation',
#  14960: 'HOBBIES_1_061_CA_1_evaluation',
#  14970: 'HOBBIES_1_062_CA_1_evaluation',
#  14980: 'HOBBIES_1_063_CA_1_evaluation',
#  14990: 'HOBBIES_1_064_CA_1_evaluation',
#  15000: 'HOBBIES_1_065_CA_1_evaluation',
#  15010: 'HOBBIES_1_066_CA_1_evaluation',
#  15020: 'HOBBIES_1_067_CA_1_evaluation',
#  15030: 'HOBBIES_1_068_CA_1_evaluation',
#  15040: 'HOBBIES_1_069_CA_1_evaluation',
#  15050: 'HOBBIES_1_070_CA_1_evaluation',
#  15060: 'HOBBIES_1_072_CA_1_evaluation',
#  15070: 'HOBBIES_1_073_CA_1_evaluation',
#  15080: 'HOBBIES_1_074_CA_1_evaluation',
#  15090: 'HOBBIES_1_075_CA_1_evaluation',
#  15100: 'HOBBIES_1_076_CA_1_evaluation',
#  15110: 'HOBBIES_1_077_CA_1_evaluation',
#  15120: 'HOBBIES_1_078_CA_1_evaluation',
#  15130: 'HOBBIES_1_079_CA_1_evaluation',
#  15140: 'HOBBIES_1_080_CA_1_evaluation',
#  15150: 'HOBBIES_1_081_CA_1_evaluation',
#  15160: 'HOBBIES_1_082_CA_1_evaluation',
#  15170: 'HOBBIES_1_083_CA_1_evaluation',
#  15180: 'HOBBIES_1_084_CA_1_evaluation',
#  15190: 'HOBBIES_1_085_CA_1_evaluation',
#  15200: 'HOBBIES_1_086_CA_1_evaluation',
#  15210: 'HOBBIES_1_087_CA_1_evaluation',
#  15220: 'HOBBIES_1_088_CA_1_evaluation',
#  15230: 'HOBBIES_1_089_CA_1_evaluation',
#  15240: 'HOBBIES_1_090_CA_1_evaluation',
#  15250: 'HOBBIES_1_091_CA_1_evaluation',
#  15260: 'HOBBIES_1_092_CA_1_evaluation',
#  15270: 'HOBBIES_1_093_CA_1_evaluation',
#  15280: 'HOBBIES_1_094_CA_1_evaluation',
#  15290: 'HOBBIES_1_095_CA_1_evaluation',
#  15300: 'HOBBIES_1_097_CA_1_evaluation',
#  15310: 'HOBBIES_1_098_CA_1_evaluation',
#  15320: 'HOBBIES_1_099_CA_1_evaluation',
#  15330: 'HOBBIES_1_100_CA_1_evaluation',
#  15340: 'HOBBIES_1_102_CA_1_evaluation',
#  15350: 'HOBBIES_1_103_CA_1_evaluation',
#  15360: 'HOBBIES_1_104_CA_1_evaluation',
#  15370: 'HOBBIES_1_105_CA_1_evaluation',
#  15380: 'HOBBIES_1_106_CA_1_evaluation',
#  15390: 'HOBBIES_1_107_CA_1_evaluation',
#  15400: 'HOBBIES_1_108_CA_1_evaluation',
#  15410: 'HOBBIES_1_109_CA_1_evaluation',
#  15420: 'HOBBIES_1_110_CA_1_evaluation',
#  15430: 'HOBBIES_1_111_CA_1_evaluation',
#  15440: 'HOBBIES_1_112_CA_1_evaluation',
#  15450: 'HOBBIES_1_113_CA_1_evaluation',
#  15460: 'HOBBIES_1_114_CA_1_evaluation',
#  15470: 'HOBBIES_1_115_CA_1_evaluation',
#  15480: 'HOBBIES_1_116_CA_1_evaluation',
#  15490: 'HOBBIES_1_117_CA_1_evaluation',
#  15500: 'HOBBIES_1_118_CA_1_evaluation',
#  15510: 'HOBBIES_1_119_CA_1_evaluation',
#  15520: 'HOBBIES_1_120_CA_1_evaluation',
#  15530: 'HOBBIES_1_121_CA_1_evaluation',
#  15540: 'HOBBIES_1_122_CA_1_evaluation',
#  15550: 'HOBBIES_1_123_CA_1_evaluation',
#  15560: 'HOBBIES_1_124_CA_1_evaluation',
#  15570: 'HOBBIES_1_125_CA_1_evaluation',
#  15580: 'HOBBIES_1_126_CA_1_evaluation',
#  15590: 'HOBBIES_1_127_CA_1_evaluation',
#  15600: 'HOBBIES_1_128_CA_1_evaluation',
#  15610: 'HOBBIES_1_129_CA_1_evaluation',
#  15620: 'HOBBIES_1_130_CA_1_evaluation',
#  15630: 'HOBBIES_1_131_CA_1_evaluation',
#  15640: 'HOBBIES_1_132_CA_1_evaluation',
#  15650: 'HOBBIES_1_133_CA_1_evaluation',
#  15660: 'HOBBIES_1_134_CA_1_evaluation',
#  15670: 'HOBBIES_1_135_CA_1_evaluation',
#  15680: 'HOBBIES_1_136_CA_1_evaluation',
#  15690: 'HOBBIES_1_137_CA_1_evaluation',
#  15700: 'HOBBIES_1_138_CA_1_evaluation',
#  15710: 'HOBBIES_1_139_CA_1_evaluation',
#  15720: 'HOBBIES_1_140_CA_1_evaluation',
#  15730: 'HOBBIES_1_141_CA_1_evaluation',
#  15740: 'HOBBIES_1_142_CA_1_evaluation',
#  15750: 'HOBBIES_1_143_CA_1_evaluation',
#  15760: 'HOBBIES_1_144_CA_1_evaluation',
#  15770: 'HOBBIES_1_145_CA_1_evaluation',
#  15780: 'HOBBIES_1_146_CA_1_evaluation',
#  15790: 'HOBBIES_1_147_CA_1_evaluation',
#  15800: 'HOBBIES_1_148_CA_1_evaluation',
#  15810: 'HOBBIES_1_149_CA_1_evaluation',
#  15820: 'HOBBIES_1_150_CA_1_evaluation',
#  15830: 'HOBBIES_1_151_CA_1_evaluation',
#  15840: 'HOBBIES_1_152_CA_1_evaluation',
#  15850: 'HOBBIES_1_153_CA_1_evaluation',
#  15860: 'HOBBIES_1_154_CA_1_evaluation',
#  15870: 'HOBBIES_1_155_CA_1_evaluation',
#  15880: 'HOBBIES_1_156_CA_1_evaluation',
#  15890: 'HOBBIES_1_157_CA_1_evaluation',
#  15900: 'HOBBIES_1_158_CA_1_evaluation',
#  15910: 'HOBBIES_1_159_CA_1_evaluation',
#  15920: 'HOBBIES_1_160_CA_1_evaluation',
#  15930: 'HOBBIES_1_161_CA_1_evaluation',
#  15940: 'HOBBIES_1_162_CA_1_evaluation',
#  15950: 'HOBBIES_1_163_CA_1_evaluation',
#  15960: 'HOBBIES_1_164_CA_1_evaluation',
#  15970: 'HOBBIES_1_165_CA_1_evaluation',
#  15980: 'HOBBIES_1_166_CA_1_evaluation',
#  15990: 'HOBBIES_1_167_CA_1_evaluation',
#  16000: 'HOBBIES_1_168_CA_1_evaluation',
#  16010: 'HOBBIES_1_169_CA_1_evaluation',
#  16020: 'HOBBIES_1_170_CA_1_evaluation',
#  16030: 'HOBBIES_1_171_CA_1_evaluation',
#  16040: 'HOBBIES_1_172_CA_1_evaluation',
#  16050: 'HOBBIES_1_173_CA_1_evaluation',
#  16060: 'HOBBIES_1_174_CA_1_evaluation',
#  16070: 'HOBBIES_1_175_CA_1_evaluation',
#  16080: 'HOBBIES_1_176_CA_1_evaluation',
#  16090: 'HOBBIES_1_177_CA_1_evaluation',
#  16100: 'HOBBIES_1_178_CA_1_evaluation',
#  16110: 'HOBBIES_1_179_CA_1_evaluation',
#  16120: 'HOBBIES_1_180_CA_1_evaluation',
#  16130: 'HOBBIES_1_181_CA_1_evaluation',
#  16140: 'HOBBIES_1_183_CA_1_evaluation',
#  16150: 'HOBBIES_1_184_CA_1_evaluation',
#  16160: 'HOBBIES_1_185_CA_1_evaluation',
#  16170: 'HOBBIES_1_186_CA_1_evaluation',
#  16180: 'HOBBIES_1_187_CA_1_evaluation',
#  16190: 'HOBBIES_1_188_CA_1_evaluation',
#  16200: 'HOBBIES_1_189_CA_1_evaluation',
#  16210: 'HOBBIES_1_190_CA_1_evaluation',
#  16220: 'HOBBIES_1_191_CA_1_evaluation',
#  16230: 'HOBBIES_1_192_CA_1_evaluation',
#  16240: 'HOBBIES_1_193_CA_1_evaluation',
#  16250: 'HOBBIES_1_194_CA_1_evaluation',
#  16260: 'HOBBIES_1_195_CA_1_evaluation',
#  16270: 'HOBBIES_1_197_CA_1_evaluation',
#  16280: 'HOBBIES_1_198_CA_1_evaluation',
#  16290: 'HOBBIES_1_199_CA_1_evaluation',
#  16300: 'HOBBIES_1_200_CA_1_evaluation',
#  16310: 'HOBBIES_1_201_CA_1_evaluation',
#  16320: 'HOBBIES_1_202_CA_1_evaluation',
#  16330: 'HOBBIES_1_203_CA_1_evaluation',
#  16340: 'HOBBIES_1_204_CA_1_evaluation',
#  16350: 'HOBBIES_1_205_CA_1_evaluation',
#  16360: 'HOBBIES_1_206_CA_1_evaluation',
#  16370: 'HOBBIES_1_207_CA_1_evaluation',
#  16380: 'HOBBIES_1_208_CA_1_evaluation',
#  16390: 'HOBBIES_1_209_CA_1_evaluation',
#  16400: 'HOBBIES_1_210_CA_1_evaluation',
#  16410: 'HOBBIES_1_211_CA_1_evaluation',
#  16420: 'HOBBIES_1_212_CA_1_evaluation',
#  16430: 'HOBBIES_1_213_CA_1_evaluation',
#  16440: 'HOBBIES_1_214_CA_1_evaluation',
#  16450: 'HOBBIES_1_215_CA_1_evaluation',
#  16460: 'HOBBIES_1_216_CA_1_evaluation',
#  16470: 'HOBBIES_1_217_CA_1_evaluation',
#  16480: 'HOBBIES_1_218_CA_1_evaluation',
#  16490: 'HOBBIES_1_219_CA_1_evaluation',
#  16500: 'HOBBIES_1_220_CA_1_evaluation',
#  16510: 'HOBBIES_1_221_CA_1_evaluation',
#  16520: 'HOBBIES_1_223_CA_1_evaluation',
#  16530: 'HOBBIES_1_224_CA_1_evaluation',
#  16540: 'HOBBIES_1_225_CA_1_evaluation',
#  16550: 'HOBBIES_1_226_CA_1_evaluation',
#  16560: 'HOBBIES_1_227_CA_1_evaluation',
#  16570: 'HOBBIES_1_228_CA_1_evaluation',
#  16580: 'HOBBIES_1_229_CA_1_evaluation',
#  16590: 'HOBBIES_1_230_CA_1_evaluation',
#  16600: 'HOBBIES_1_231_CA_1_evaluation',
#  16610: 'HOBBIES_1_232_CA_1_evaluation',
#  16620: 'HOBBIES_1_233_CA_1_evaluation',
#  16630: 'HOBBIES_1_234_CA_1_evaluation',
#  16640: 'HOBBIES_1_235_CA_1_evaluation',
#  16650: 'HOBBIES_1_236_CA_1_evaluation',
#  16660: 'HOBBIES_1_237_CA_1_evaluation',
#  16670: 'HOBBIES_1_238_CA_1_evaluation',
#  16680: 'HOBBIES_1_239_CA_1_evaluation',
#  16690: 'HOBBIES_1_240_CA_1_evaluation',
#  16700: 'HOBBIES_1_241_CA_1_evaluation',
#  16710: 'HOBBIES_1_242_CA_1_evaluation',
#  16720: 'HOBBIES_1_243_CA_1_evaluation',
#  16730: 'HOBBIES_1_244_CA_1_evaluation',
#  16740: 'HOBBIES_1_245_CA_1_evaluation',
#  16750: 'HOBBIES_1_246_CA_1_evaluation',
#  16760: 'HOBBIES_1_247_CA_1_evaluation',
#  16770: 'HOBBIES_1_248_CA_1_evaluation',
#  16780: 'HOBBIES_1_249_CA_1_evaluation',
#  16790: 'HOBBIES_1_250_CA_1_evaluation',
#  16800: 'HOBBIES_1_251_CA_1_evaluation',
#  16810: 'HOBBIES_1_252_CA_1_evaluation',
#  16820: 'HOBBIES_1_253_CA_1_evaluation',
#  16830: 'HOBBIES_1_254_CA_1_evaluation',
#  16840: 'HOBBIES_1_255_CA_1_evaluation',
#  16850: 'HOBBIES_1_256_CA_1_evaluation',
#  16860: 'HOBBIES_1_257_CA_1_evaluation',
#  16870: 'HOBBIES_1_258_CA_1_evaluation',
#  16880: 'HOBBIES_1_259_CA_1_evaluation',
#  16890: 'HOBBIES_1_260_CA_1_evaluation',
#  16900: 'HOBBIES_1_261_CA_1_evaluation',
#  16910: 'HOBBIES_1_262_CA_1_evaluation',
#  16920: 'HOBBIES_1_263_CA_1_evaluation',
#  16930: 'HOBBIES_1_264_CA_1_evaluation',
#  16940: 'HOBBIES_1_265_CA_1_evaluation',
#  16950: 'HOBBIES_1_266_CA_1_evaluation',
#  16960: 'HOBBIES_1_267_CA_1_evaluation',
#  16970: 'HOBBIES_1_268_CA_1_evaluation',
#  16980: 'HOBBIES_1_269_CA_1_evaluation',
#  16990: 'HOBBIES_1_270_CA_1_evaluation',
#  17000: 'HOBBIES_1_271_CA_1_evaluation',
#  17010: 'HOBBIES_1_272_CA_1_evaluation',
#  17020: 'HOBBIES_1_273_CA_1_evaluation',
#  17030: 'HOBBIES_1_274_CA_1_evaluation',
#  17040: 'HOBBIES_1_275_CA_1_evaluation',
#  17050: 'HOBBIES_1_276_CA_1_evaluation',
#  17060: 'HOBBIES_1_277_CA_1_evaluation',
#  17070: 'HOBBIES_1_278_CA_1_evaluation',
#  17080: 'HOBBIES_1_279_CA_1_evaluation',
#  17090: 'HOBBIES_1_280_CA_1_evaluation',
#  17100: 'HOBBIES_1_281_CA_1_evaluation',
#  17110: 'HOBBIES_1_282_CA_1_evaluation',
#  17120: 'HOBBIES_1_283_CA_1_evaluation',
#  17130: 'HOBBIES_1_284_CA_1_evaluation',
#  17140: 'HOBBIES_1_285_CA_1_evaluation',
#  17150: 'HOBBIES_1_286_CA_1_evaluation',
#  17160: 'HOBBIES_1_287_CA_1_evaluation',
#  17170: 'HOBBIES_1_288_CA_1_evaluation',
#  17180: 'HOBBIES_1_289_CA_1_evaluation',
#  17190: 'HOBBIES_1_290_CA_1_evaluation',
#  17200: 'HOBBIES_1_292_CA_1_evaluation',
#  17210: 'HOBBIES_1_293_CA_1_evaluation',
#  17220: 'HOBBIES_1_294_CA_1_evaluation',
#  17230: 'HOBBIES_1_295_CA_1_evaluation',
#  17240: 'HOBBIES_1_296_CA_1_evaluation',
#  17250: 'HOBBIES_1_297_CA_1_evaluation',
#  17260: 'HOBBIES_1_298_CA_1_evaluation',
#  17270: 'HOBBIES_1_299_CA_1_evaluation',
#  17280: 'HOBBIES_1_300_CA_1_evaluation',
#  17290: 'HOBBIES_1_301_CA_1_evaluation',
#  17300: 'HOBBIES_1_302_CA_1_evaluation',
#  17310: 'HOBBIES_1_303_CA_1_evaluation',
#  17320: 'HOBBIES_1_304_CA_1_evaluation',
#  17330: 'HOBBIES_1_305_CA_1_evaluation',
#  17340: 'HOBBIES_1_306_CA_1_evaluation',
#  17350: 'HOBBIES_1_307_CA_1_evaluation',
#  17360: 'HOBBIES_1_308_CA_1_evaluation',
#  17370: 'HOBBIES_1_309_CA_1_evaluation',
#  17380: 'HOBBIES_1_310_CA_1_evaluation',
#  17390: 'HOBBIES_1_311_CA_1_evaluation',
#  17400: 'HOBBIES_1_312_CA_1_evaluation',
#  17410: 'HOBBIES_1_313_CA_1_evaluation',
#  17420: 'HOBBIES_1_314_CA_1_evaluation',
#  17430: 'HOBBIES_1_315_CA_1_evaluation',
#  17440: 'HOBBIES_1_316_CA_1_evaluation',
#  17450: 'HOBBIES_1_317_CA_1_evaluation',
#  17460: 'HOBBIES_1_318_CA_1_evaluation',
#  17470: 'HOBBIES_1_319_CA_1_evaluation',
#  17480: 'HOBBIES_1_320_CA_1_evaluation',
#  17490: 'HOBBIES_1_321_CA_1_evaluation',
#  17500: 'HOBBIES_1_322_CA_1_evaluation',
#  17510: 'HOBBIES_1_323_CA_1_evaluation',
#  17520: 'HOBBIES_1_324_CA_1_evaluation',
#  17530: 'HOBBIES_1_325_CA_1_evaluation',
#  17540: 'HOBBIES_1_326_CA_1_evaluation',
#  17550: 'HOBBIES_1_327_CA_1_evaluation',
#  17560: 'HOBBIES_1_328_CA_1_evaluation',
#  17570: 'HOBBIES_1_329_CA_1_evaluation',
#  17580: 'HOBBIES_1_330_CA_1_evaluation',
#  17590: 'HOBBIES_1_331_CA_1_evaluation',
#  17600: 'HOBBIES_1_332_CA_1_evaluation',
#  17610: 'HOBBIES_1_333_CA_1_evaluation',
#  17620: 'HOBBIES_1_334_CA_1_evaluation',
#  17630: 'HOBBIES_1_335_CA_1_evaluation',
#  17640: 'HOBBIES_1_336_CA_1_evaluation',
#  17650: 'HOBBIES_1_337_CA_1_evaluation',
#  17660: 'HOBBIES_1_338_CA_1_evaluation',
#  17670: 'HOBBIES_1_339_CA_1_evaluation',
#  17680: 'HOBBIES_1_340_CA_1_evaluation',
#  17690: 'HOBBIES_1_341_CA_1_evaluation',
#  17700: 'HOBBIES_1_342_CA_1_evaluation',
#  17710: 'HOBBIES_1_343_CA_1_evaluation',
#  17720: 'HOBBIES_1_344_CA_1_evaluation',
#  17730: 'HOBBIES_1_345_CA_1_evaluation',
#  17740: 'HOBBIES_1_346_CA_1_evaluation',
#  17750: 'HOBBIES_1_347_CA_1_evaluation',
#  17760: 'HOBBIES_1_348_CA_1_evaluation',
#  17770: 'HOBBIES_1_349_CA_1_evaluation',
#  17780: 'HOBBIES_1_350_CA_1_evaluation',
#  17790: 'HOBBIES_1_351_CA_1_evaluation',
#  17800: 'HOBBIES_1_352_CA_1_evaluation',
#  17810: 'HOBBIES_1_353_CA_1_evaluation',
#  17820: 'HOBBIES_1_354_CA_1_evaluation',
#  17830: 'HOBBIES_1_355_CA_1_evaluation',
#  17840: 'HOBBIES_1_356_CA_1_evaluation',
#  17850: 'HOBBIES_1_357_CA_1_evaluation',
#  17860: 'HOBBIES_1_358_CA_1_evaluation',
#  17870: 'HOBBIES_1_359_CA_1_evaluation',
#  17880: 'HOBBIES_1_360_CA_1_evaluation',
#  17890: 'HOBBIES_1_361_CA_1_evaluation',
#  17900: 'HOBBIES_1_362_CA_1_evaluation',
#  17910: 'HOBBIES_1_363_CA_1_evaluation',
#  17920: 'HOBBIES_1_364_CA_1_evaluation',
#  17930: 'HOBBIES_1_365_CA_1_evaluation',
#  17940: 'HOBBIES_1_366_CA_1_evaluation',
#  17950: 'HOBBIES_1_367_CA_1_evaluation',
#  17960: 'HOBBIES_1_368_CA_1_evaluation',
#  17970: 'HOBBIES_1_369_CA_1_evaluation',
#  17980: 'HOBBIES_1_370_CA_1_evaluation',
#  17990: 'HOBBIES_1_371_CA_1_evaluation',
#  18000: 'HOBBIES_1_372_CA_1_evaluation',
#  18010: 'HOBBIES_1_373_CA_1_evaluation',
#  18020: 'HOBBIES_1_374_CA_1_evaluation',
#  18030: 'HOBBIES_1_375_CA_1_evaluation',
#  18040: 'HOBBIES_1_376_CA_1_evaluation',
#  18050: 'HOBBIES_1_377_CA_1_evaluation',
#  18060: 'HOBBIES_1_378_CA_1_evaluation',
#  18070: 'HOBBIES_1_379_CA_1_evaluation',
#  18080: 'HOBBIES_1_380_CA_1_evaluation',
#  18090: 'HOBBIES_1_381_CA_1_evaluation',
#  18100: 'HOBBIES_1_382_CA_1_evaluation',
#  18110: 'HOBBIES_1_383_CA_1_evaluation',
#  18120: 'HOBBIES_1_384_CA_1_evaluation',
#  18130: 'HOBBIES_1_385_CA_1_evaluation',
#  18140: 'HOBBIES_1_386_CA_1_evaluation',
#  18150: 'HOBBIES_1_387_CA_1_evaluation',
#  18160: 'HOBBIES_1_388_CA_1_evaluation',
#  18170: 'HOBBIES_1_389_CA_1_evaluation',
#  18180: 'HOBBIES_1_390_CA_1_evaluation',
#  18190: 'HOBBIES_1_391_CA_1_evaluation',
#  18200: 'HOBBIES_1_392_CA_1_evaluation',
#  18210: 'HOBBIES_1_393_CA_1_evaluation',
#  18220: 'HOBBIES_1_394_CA_1_evaluation',
#  18230: 'HOBBIES_1_395_CA_1_evaluation',
#  18240: 'HOBBIES_1_396_CA_1_evaluation',
#  18250: 'HOBBIES_1_397_CA_1_evaluation',
#  18260: 'HOBBIES_1_398_CA_1_evaluation',
#  18270: 'HOBBIES_1_399_CA_1_evaluation',
#  18280: 'HOBBIES_1_400_CA_1_evaluation',
#  18290: 'HOBBIES_1_401_CA_1_evaluation',
#  18300: 'HOBBIES_1_402_CA_1_evaluation',
#  18310: 'HOBBIES_1_403_CA_1_evaluation',
#  18320: 'HOBBIES_1_404_CA_1_evaluation',
#  18330: 'HOBBIES_1_405_CA_1_evaluation',
#  18340: 'HOBBIES_1_406_CA_1_evaluation',
#  18350: 'HOBBIES_1_407_CA_1_evaluation',
#  18360: 'HOBBIES_1_408_CA_1_evaluation',
#  18370: 'HOBBIES_1_409_CA_1_evaluation',
#  18380: 'HOBBIES_1_410_CA_1_evaluation',
#  18390: 'HOBBIES_1_411_CA_1_evaluation',
#  18400: 'HOBBIES_1_412_CA_1_evaluation',
#  18410: 'HOBBIES_1_413_CA_1_evaluation',
#  18420: 'HOBBIES_1_414_CA_1_evaluation',
#  18430: 'HOBBIES_1_415_CA_1_evaluation',
#  18440: 'HOBBIES_1_416_CA_1_evaluation',
#  18450: 'HOBBIES_1_417_CA_1_evaluation',
#  18460: 'HOBBIES_1_418_CA_1_evaluation',
#  18470: 'HOBBIES_1_419_CA_1_evaluation',
#  18480: 'HOBBIES_1_420_CA_1_evaluation',
#  18490: 'HOBBIES_1_421_CA_1_evaluation',
#  18500: 'HOBBIES_1_422_CA_1_evaluation',
#  18510: 'HOBBIES_1_423_CA_1_evaluation',
#  18520: 'HOBBIES_1_424_CA_1_evaluation',
#  18530: 'HOBBIES_2_001_CA_1_evaluation',
#  18540: 'HOBBIES_2_002_CA_1_evaluation',
#  18550: 'HOBBIES_2_003_CA_1_evaluation',
#  18560: 'HOBBIES_2_004_CA_1_evaluation',
#  18570: 'HOBBIES_2_005_CA_1_evaluation',
#  18580: 'HOBBIES_2_006_CA_1_evaluation',
#  18590: 'HOBBIES_2_007_CA_1_evaluation',
#  18600: 'HOBBIES_2_008_CA_1_evaluation',
#  18610: 'HOBBIES_2_009_CA_1_evaluation',
#  18620: 'HOBBIES_2_010_CA_1_evaluation',
#  18630: 'HOBBIES_2_011_CA_1_evaluation',
#  18640: 'HOBBIES_2_012_CA_1_evaluation',
#  18650: 'HOBBIES_2_013_CA_1_evaluation',
#  18660: 'HOBBIES_2_014_CA_1_evaluation',
#  18670: 'HOBBIES_2_015_CA_1_evaluation',
#  18680: 'HOBBIES_2_016_CA_1_evaluation',
#  18690: 'HOBBIES_2_017_CA_1_evaluation',
#  18700: 'HOBBIES_2_018_CA_1_evaluation',
#  18710: 'HOBBIES_2_019_CA_1_evaluation',
#  18720: 'HOBBIES_2_020_CA_1_evaluation',
#  18730: 'HOBBIES_2_021_CA_1_evaluation',
#  18740: 'HOBBIES_2_022_CA_1_evaluation',
#  18750: 'HOBBIES_2_023_CA_1_evaluation',
#  18760: 'HOBBIES_2_024_CA_1_evaluation',
#  18770: 'HOBBIES_2_025_CA_1_evaluation',
#  18780: 'HOBBIES_2_026_CA_1_evaluation',
#  18790: 'HOBBIES_2_027_CA_1_evaluation',
#  18800: 'HOBBIES_2_028_CA_1_evaluation',
#  18810: 'HOBBIES_2_029_CA_1_evaluation',
#  18820: 'HOBBIES_2_030_CA_1_evaluation',
#  18830: 'HOBBIES_2_031_CA_1_evaluation',
#  18840: 'HOBBIES_2_032_CA_1_evaluation',
#  18850: 'HOBBIES_2_033_CA_1_evaluation',
#  18860: 'HOBBIES_2_034_CA_1_evaluation',
#  18870: 'HOBBIES_2_035_CA_1_evaluation',
#  18880: 'HOBBIES_2_036_CA_1_evaluation',
#  18890: 'HOBBIES_2_037_CA_1_evaluation',
#  18900: 'HOBBIES_2_038_CA_1_evaluation',
#  18910: 'HOBBIES_2_039_CA_1_evaluation',
#  18920: 'HOBBIES_2_040_CA_1_evaluation',
#  18930: 'HOBBIES_2_041_CA_1_evaluation',
#  18940: 'HOBBIES_2_042_CA_1_evaluation',
#  18950: 'HOBBIES_2_043_CA_1_evaluation',
#  18960: 'HOBBIES_2_044_CA_1_evaluation',
#  18970: 'HOBBIES_2_045_CA_1_evaluation',
#  18980: 'HOBBIES_2_046_CA_1_evaluation',
#  18990: 'HOBBIES_2_047_CA_1_evaluation',
#  19000: 'HOBBIES_2_048_CA_1_evaluation',
#  19010: 'HOBBIES_2_049_CA_1_evaluation',
#  19020: 'HOBBIES_2_050_CA_1_evaluation',
#  19030: 'HOBBIES_2_051_CA_1_evaluation',
#  19040: 'HOBBIES_2_052_CA_1_evaluation',
#  19050: 'HOBBIES_2_053_CA_1_evaluation',
#  19060: 'HOBBIES_2_054_CA_1_evaluation',
#  19070: 'HOBBIES_2_055_CA_1_evaluation',
#  19080: 'HOBBIES_2_056_CA_1_evaluation',
#  19090: 'HOBBIES_2_057_CA_1_evaluation',
#  19100: 'HOBBIES_2_058_CA_1_evaluation',
#  19110: 'HOBBIES_2_059_CA_1_evaluation',
#  19120: 'HOBBIES_2_060_CA_1_evaluation',
#  19130: 'HOBBIES_2_061_CA_1_evaluation',
#  19140: 'HOBBIES_2_062_CA_1_evaluation',
#  19150: 'HOBBIES_2_063_CA_1_evaluation',
#  19160: 'HOBBIES_2_064_CA_1_evaluation',
#  19170: 'HOBBIES_2_065_CA_1_evaluation',
#  19180: 'HOBBIES_2_066_CA_1_evaluation',
#  19190: 'HOBBIES_2_067_CA_1_evaluation',
#  19200: 'HOBBIES_2_068_CA_1_evaluation',
#  19210: 'HOBBIES_2_069_CA_1_evaluation',
#  19220: 'HOBBIES_2_070_CA_1_evaluation',
#  19230: 'HOBBIES_2_071_CA_1_evaluation',
#  19240: 'HOBBIES_2_072_CA_1_evaluation',
#  19250: 'HOBBIES_2_073_CA_1_evaluation',
#  19260: 'HOBBIES_2_074_CA_1_evaluation',
#  19270: 'HOBBIES_2_075_CA_1_evaluation',
#  19280: 'HOBBIES_2_076_CA_1_evaluation',
#  19290: 'HOBBIES_2_077_CA_1_evaluation',
#  19300: 'HOBBIES_2_078_CA_1_evaluation',
#  19310: 'HOBBIES_2_079_CA_1_evaluation',
#  19320: 'HOBBIES_2_080_CA_1_evaluation',
#  19330: 'HOBBIES_2_081_CA_1_evaluation',
#  19340: 'HOBBIES_2_082_CA_1_evaluation',
#  19350: 'HOBBIES_2_083_CA_1_evaluation',
#  19360: 'HOBBIES_2_084_CA_1_evaluation',
#  19370: 'HOBBIES_2_085_CA_1_evaluation',
#  19380: 'HOBBIES_2_086_CA_1_evaluation',
#  19390: 'HOBBIES_2_087_CA_1_evaluation',
#  19400: 'HOBBIES_2_088_CA_1_evaluation',
#  19410: 'HOBBIES_2_089_CA_1_evaluation',
#  19420: 'HOBBIES_2_090_CA_1_evaluation',
#  19430: 'HOBBIES_2_091_CA_1_evaluation',
#  19440: 'HOBBIES_2_092_CA_1_evaluation',
#  19450: 'HOBBIES_2_093_CA_1_evaluation',
#  19460: 'HOBBIES_2_094_CA_1_evaluation',
#  19470: 'HOBBIES_2_095_CA_1_evaluation',
#  19480: 'HOBBIES_2_096_CA_1_evaluation',
#  19490: 'HOBBIES_2_097_CA_1_evaluation',
#  19500: 'HOBBIES_2_098_CA_1_evaluation',
#  19510: 'HOBBIES_2_099_CA_1_evaluation',
#  19520: 'HOBBIES_2_100_CA_1_evaluation',
#  19530: 'HOBBIES_2_101_CA_1_evaluation',
#  19540: 'HOBBIES_2_102_CA_1_evaluation',
#  19550: 'HOBBIES_2_103_CA_1_evaluation',
#  19560: 'HOBBIES_2_104_CA_1_evaluation',
#  19570: 'HOBBIES_2_105_CA_1_evaluation',
#  19580: 'HOBBIES_2_106_CA_1_evaluation',
#  19590: 'HOBBIES_2_107_CA_1_evaluation',
#  19600: 'HOBBIES_2_108_CA_1_evaluation',
#  19610: 'HOBBIES_2_109_CA_1_evaluation',
#  19620: 'HOBBIES_2_110_CA_1_evaluation',
#  19630: 'HOBBIES_2_111_CA_1_evaluation',
#  19640: 'HOBBIES_2_112_CA_1_evaluation',
#  19650: 'HOBBIES_2_113_CA_1_evaluation',
#  19660: 'HOBBIES_2_114_CA_1_evaluation',
#  19670: 'HOBBIES_2_115_CA_1_evaluation',
#  19680: 'HOBBIES_2_116_CA_1_evaluation',
#  19690: 'HOBBIES_2_117_CA_1_evaluation',
#  19700: 'HOBBIES_2_118_CA_1_evaluation',
#  19710: 'HOBBIES_2_119_CA_1_evaluation',
#  19720: 'HOBBIES_2_120_CA_1_evaluation',
#  19730: 'HOBBIES_2_121_CA_1_evaluation',
#  19740: 'HOBBIES_2_122_CA_1_evaluation',
#  19750: 'HOBBIES_2_123_CA_1_evaluation',
#  19760: 'HOBBIES_2_124_CA_1_evaluation',
#  19770: 'HOBBIES_2_125_CA_1_evaluation',
#  19780: 'HOBBIES_2_126_CA_1_evaluation',
#  19790: 'HOBBIES_2_127_CA_1_evaluation',
#  19800: 'HOBBIES_2_128_CA_1_evaluation',
#  19810: 'HOBBIES_2_129_CA_1_evaluation',
#  19820: 'HOBBIES_2_130_CA_1_evaluation',
#  19830: 'HOBBIES_2_131_CA_1_evaluation',
#  19840: 'HOBBIES_2_132_CA_1_evaluation',
#  19850: 'HOBBIES_2_133_CA_1_evaluation',
#  19860: 'HOBBIES_2_134_CA_1_evaluation',
#  19870: 'HOBBIES_2_135_CA_1_evaluation',
#  19880: 'HOBBIES_2_136_CA_1_evaluation',
#  19890: 'HOBBIES_2_137_CA_1_evaluation',
#  19900: 'HOBBIES_2_138_CA_1_evaluation',
#  19910: 'HOBBIES_2_139_CA_1_evaluation',
#  19920: 'HOBBIES_2_140_CA_1_evaluation',
#  19930: 'HOBBIES_2_141_CA_1_evaluation',
#  19940: 'HOBBIES_2_142_CA_1_evaluation',
#  19950: 'HOBBIES_2_143_CA_1_evaluation',
#  19960: 'HOBBIES_2_144_CA_1_evaluation',
#  19970: 'HOBBIES_2_145_CA_1_evaluation',
#  19980: 'HOBBIES_2_146_CA_1_evaluation',
#  19990: 'HOBBIES_2_147_CA_1_evaluation',
#  20000: 'HOBBIES_2_148_CA_1_evaluation',
#  20010: 'HOBBIES_2_149_CA_1_evaluation',
#  20020: 'HOUSEHOLD_1_001_CA_1_evaluation',
#  20030: 'HOUSEHOLD_1_002_CA_1_evaluation',
#  20040: 'HOUSEHOLD_1_003_CA_1_evaluation',
#  20050: 'HOUSEHOLD_1_004_CA_1_evaluation',
#  20060: 'HOUSEHOLD_1_005_CA_1_evaluation',
#  20070: 'HOUSEHOLD_1_006_CA_1_evaluation',
#  20080: 'HOUSEHOLD_1_007_CA_1_evaluation',
#  20090: 'HOUSEHOLD_1_008_CA_1_evaluation',
#  20100: 'HOUSEHOLD_1_009_CA_1_evaluation',
#  20110: 'HOUSEHOLD_1_010_CA_1_evaluation',
#  20120: 'HOUSEHOLD_1_011_CA_1_evaluation',
#  20130: 'HOUSEHOLD_1_012_CA_1_evaluation',
#  20140: 'HOUSEHOLD_1_013_CA_1_evaluation',
#  20150: 'HOUSEHOLD_1_014_CA_1_evaluation',
#  20160: 'HOUSEHOLD_1_015_CA_1_evaluation',
#  20170: 'HOUSEHOLD_1_016_CA_1_evaluation',
#  20180: 'HOUSEHOLD_1_017_CA_1_evaluation',
#  20190: 'HOUSEHOLD_1_018_CA_1_evaluation',
#  20200: 'HOUSEHOLD_1_019_CA_1_evaluation',
#  20210: 'HOUSEHOLD_1_020_CA_1_evaluation',
#  20220: 'HOUSEHOLD_1_021_CA_1_evaluation',
#  20230: 'HOUSEHOLD_1_022_CA_1_evaluation',
#  20240: 'HOUSEHOLD_1_023_CA_1_evaluation',
#  20250: 'HOUSEHOLD_1_024_CA_1_evaluation',
#  20260: 'HOUSEHOLD_1_025_CA_1_evaluation',
#  20270: 'HOUSEHOLD_1_026_CA_1_evaluation',
#  20280: 'HOUSEHOLD_1_027_CA_1_evaluation',
#  20290: 'HOUSEHOLD_1_028_CA_1_evaluation',
#  20300: 'HOUSEHOLD_1_029_CA_1_evaluation',
#  20310: 'HOUSEHOLD_1_030_CA_1_evaluation',
#  20320: 'HOUSEHOLD_1_032_CA_1_evaluation',
#  20330: 'HOUSEHOLD_1_033_CA_1_evaluation',
#  20340: 'HOUSEHOLD_1_034_CA_1_evaluation',
#  20350: 'HOUSEHOLD_1_035_CA_1_evaluation',
#  20360: 'HOUSEHOLD_1_036_CA_1_evaluation',
#  20370: 'HOUSEHOLD_1_037_CA_1_evaluation',
#  20380: 'HOUSEHOLD_1_038_CA_1_evaluation',
#  20390: 'HOUSEHOLD_1_039_CA_1_evaluation',
#  20400: 'HOUSEHOLD_1_040_CA_1_evaluation',
#  20410: 'HOUSEHOLD_1_042_CA_1_evaluation',
#  20420: 'HOUSEHOLD_1_043_CA_1_evaluation',
#  20430: 'HOUSEHOLD_1_044_CA_1_evaluation',
#  20440: 'HOUSEHOLD_1_045_CA_1_evaluation',
#  20450: 'HOUSEHOLD_1_046_CA_1_evaluation',
#  20460: 'HOUSEHOLD_1_047_CA_1_evaluation',
#  20470: 'HOUSEHOLD_1_048_CA_1_evaluation',
#  20480: 'HOUSEHOLD_1_049_CA_1_evaluation',
#  20490: 'HOUSEHOLD_1_050_CA_1_evaluation',
#  20500: 'HOUSEHOLD_1_051_CA_1_evaluation',
#  20510: 'HOUSEHOLD_1_052_CA_1_evaluation',
#  20520: 'HOUSEHOLD_1_053_CA_1_evaluation',
#  20530: 'HOUSEHOLD_1_054_CA_1_evaluation',
#  20540: 'HOUSEHOLD_1_055_CA_1_evaluation',
#  20550: 'HOUSEHOLD_1_056_CA_1_evaluation',
#  20560: 'HOUSEHOLD_1_057_CA_1_evaluation',
#  20570: 'HOUSEHOLD_1_058_CA_1_evaluation',
#  20580: 'HOUSEHOLD_1_059_CA_1_evaluation',
#  20590: 'HOUSEHOLD_1_060_CA_1_evaluation',
#  20600: 'HOUSEHOLD_1_061_CA_1_evaluation',
#  20610: 'HOUSEHOLD_1_062_CA_1_evaluation',
#  20620: 'HOUSEHOLD_1_063_CA_1_evaluation',
#  20630: 'HOUSEHOLD_1_064_CA_1_evaluation',
#  20640: 'HOUSEHOLD_1_065_CA_1_evaluation',
#  20650: 'HOUSEHOLD_1_066_CA_1_evaluation',
#  20660: 'HOUSEHOLD_1_067_CA_1_evaluation',
#  20670: 'HOUSEHOLD_1_068_CA_1_evaluation',
#  20680: 'HOUSEHOLD_1_069_CA_1_evaluation',
#  20690: 'HOUSEHOLD_1_070_CA_1_evaluation',
#  20700: 'HOUSEHOLD_1_071_CA_1_evaluation',
#  20710: 'HOUSEHOLD_1_072_CA_1_evaluation',
#  20720: 'HOUSEHOLD_1_073_CA_1_evaluation',
#  20730: 'HOUSEHOLD_1_074_CA_1_evaluation',
#  20740: 'HOUSEHOLD_1_075_CA_1_evaluation',
#  20750: 'HOUSEHOLD_1_076_CA_1_evaluation',
#  20760: 'HOUSEHOLD_1_077_CA_1_evaluation',
#  20770: 'HOUSEHOLD_1_078_CA_1_evaluation',
#  20780: 'HOUSEHOLD_1_079_CA_1_evaluation',
#  20790: 'HOUSEHOLD_1_080_CA_1_evaluation',
#  20800: 'HOUSEHOLD_1_081_CA_1_evaluation',
#  20810: 'HOUSEHOLD_1_082_CA_1_evaluation',
#  20820: 'HOUSEHOLD_1_083_CA_1_evaluation',
#  20830: 'HOUSEHOLD_1_085_CA_1_evaluation',
#  20840: 'HOUSEHOLD_1_086_CA_1_evaluation',
#  20850: 'HOUSEHOLD_1_087_CA_1_evaluation',
#  20860: 'HOUSEHOLD_1_088_CA_1_evaluation',
#  20870: 'HOUSEHOLD_1_089_CA_1_evaluation',
#  20880: 'HOUSEHOLD_1_090_CA_1_evaluation',
#  20890: 'HOUSEHOLD_1_091_CA_1_evaluation',
#  20900: 'HOUSEHOLD_1_092_CA_1_evaluation',
#  20910: 'HOUSEHOLD_1_093_CA_1_evaluation',
#  20920: 'HOUSEHOLD_1_094_CA_1_evaluation',
#  20930: 'HOUSEHOLD_1_095_CA_1_evaluation',
#  20940: 'HOUSEHOLD_1_096_CA_1_evaluation',
#  20950: 'HOUSEHOLD_1_097_CA_1_evaluation',
#  20960: 'HOUSEHOLD_1_098_CA_1_evaluation',
#  20970: 'HOUSEHOLD_1_099_CA_1_evaluation',
#  20980: 'HOUSEHOLD_1_100_CA_1_evaluation',
#  20990: 'HOUSEHOLD_1_101_CA_1_evaluation',
#  21000: 'HOUSEHOLD_1_102_CA_1_evaluation',
#  21010: 'HOUSEHOLD_1_103_CA_1_evaluation',
#  21020: 'HOUSEHOLD_1_104_CA_1_evaluation',
#  21030: 'HOUSEHOLD_1_105_CA_1_evaluation',
#  21040: 'HOUSEHOLD_1_106_CA_1_evaluation',
#  21050: 'HOUSEHOLD_1_107_CA_1_evaluation',
#  21060: 'HOUSEHOLD_1_108_CA_1_evaluation',
#  21070: 'HOUSEHOLD_1_109_CA_1_evaluation',
#  21080: 'HOUSEHOLD_1_110_CA_1_evaluation',
#  21090: 'HOUSEHOLD_1_112_CA_1_evaluation',
#  21100: 'HOUSEHOLD_1_113_CA_1_evaluation',
#  21110: 'HOUSEHOLD_1_114_CA_1_evaluation',
#  21120: 'HOUSEHOLD_1_115_CA_1_evaluation',
#  21130: 'HOUSEHOLD_1_116_CA_1_evaluation',
#  21140: 'HOUSEHOLD_1_117_CA_1_evaluation',
#  21150: 'HOUSEHOLD_1_118_CA_1_evaluation',
#  21160: 'HOUSEHOLD_1_119_CA_1_evaluation',
#  21170: 'HOUSEHOLD_1_120_CA_1_evaluation',
#  21180: 'HOUSEHOLD_1_121_CA_1_evaluation',
#  21190: 'HOUSEHOLD_1_122_CA_1_evaluation',
#  21200: 'HOUSEHOLD_1_123_CA_1_evaluation',
#  21210: 'HOUSEHOLD_1_124_CA_1_evaluation',
#  21220: 'HOUSEHOLD_1_125_CA_1_evaluation',
#  21230: 'HOUSEHOLD_1_126_CA_1_evaluation',
#  21240: 'HOUSEHOLD_1_127_CA_1_evaluation',
#  21250: 'HOUSEHOLD_1_128_CA_1_evaluation',
#  21260: 'HOUSEHOLD_1_129_CA_1_evaluation',
#  21270: 'HOUSEHOLD_1_130_CA_1_evaluation',
#  21280: 'HOUSEHOLD_1_131_CA_1_evaluation',
#  21290: 'HOUSEHOLD_1_132_CA_1_evaluation',
#  21300: 'HOUSEHOLD_1_133_CA_1_evaluation',
#  21310: 'HOUSEHOLD_1_134_CA_1_evaluation',
#  21320: 'HOUSEHOLD_1_135_CA_1_evaluation',
#  21330: 'HOUSEHOLD_1_136_CA_1_evaluation',
#  21340: 'HOUSEHOLD_1_137_CA_1_evaluation',
#  21350: 'HOUSEHOLD_1_138_CA_1_evaluation',
#  21360: 'HOUSEHOLD_1_139_CA_1_evaluation',
#  21370: 'HOUSEHOLD_1_140_CA_1_evaluation',
#  21380: 'HOUSEHOLD_1_141_CA_1_evaluation',
#  21390: 'HOUSEHOLD_1_142_CA_1_evaluation',
#  21400: 'HOUSEHOLD_1_143_CA_1_evaluation',
#  21410: 'HOUSEHOLD_1_144_CA_1_evaluation',
#  21420: 'HOUSEHOLD_1_145_CA_1_evaluation',
#  21430: 'HOUSEHOLD_1_146_CA_1_evaluation',
#  21440: 'HOUSEHOLD_1_147_CA_1_evaluation',
#  21450: 'HOUSEHOLD_1_148_CA_1_evaluation',
#  21460: 'HOUSEHOLD_1_149_CA_1_evaluation',
#  21470: 'HOUSEHOLD_1_150_CA_1_evaluation',
#  21480: 'HOUSEHOLD_1_151_CA_1_evaluation',
#  21490: 'HOUSEHOLD_1_152_CA_1_evaluation',
#  21500: 'HOUSEHOLD_1_153_CA_1_evaluation',
#  21510: 'HOUSEHOLD_1_154_CA_1_evaluation',
#  21520: 'HOUSEHOLD_1_155_CA_1_evaluation',
#  21530: 'HOUSEHOLD_1_156_CA_1_evaluation',
#  21540: 'HOUSEHOLD_1_157_CA_1_evaluation',
#  21550: 'HOUSEHOLD_1_158_CA_1_evaluation',
#  21560: 'HOUSEHOLD_1_159_CA_1_evaluation',
#  21570: 'HOUSEHOLD_1_160_CA_1_evaluation',
#  21580: 'HOUSEHOLD_1_161_CA_1_evaluation',
#  21590: 'HOUSEHOLD_1_162_CA_1_evaluation',
#  21600: 'HOUSEHOLD_1_163_CA_1_evaluation',
#  21610: 'HOUSEHOLD_1_164_CA_1_evaluation',
#  21620: 'HOUSEHOLD_1_165_CA_1_evaluation',
#  21630: 'HOUSEHOLD_1_166_CA_1_evaluation',
#  21640: 'HOUSEHOLD_1_167_CA_1_evaluation',
#  21650: 'HOUSEHOLD_1_168_CA_1_evaluation',
#  21660: 'HOUSEHOLD_1_169_CA_1_evaluation',
#  21670: 'HOUSEHOLD_1_170_CA_1_evaluation',
#  21680: 'HOUSEHOLD_1_171_CA_1_evaluation',
#  21690: 'HOUSEHOLD_1_172_CA_1_evaluation',
#  21700: 'HOUSEHOLD_1_173_CA_1_evaluation',
#  21710: 'HOUSEHOLD_1_174_CA_1_evaluation',
#  21720: 'HOUSEHOLD_1_175_CA_1_evaluation',
#  21730: 'HOUSEHOLD_1_176_CA_1_evaluation',
#  21740: 'HOUSEHOLD_1_177_CA_1_evaluation',
#  21750: 'HOUSEHOLD_1_178_CA_1_evaluation',
#  21760: 'HOUSEHOLD_1_179_CA_1_evaluation',
#  21770: 'HOUSEHOLD_1_180_CA_1_evaluation',
#  21780: 'HOUSEHOLD_1_181_CA_1_evaluation',
#  21790: 'HOUSEHOLD_1_182_CA_1_evaluation',
#  21800: 'HOUSEHOLD_1_183_CA_1_evaluation',
#  21810: 'HOUSEHOLD_1_184_CA_1_evaluation',
#  21820: 'HOUSEHOLD_1_185_CA_1_evaluation',
#  21830: 'HOUSEHOLD_1_186_CA_1_evaluation',
#  21840: 'HOUSEHOLD_1_187_CA_1_evaluation',
#  21850: 'HOUSEHOLD_1_188_CA_1_evaluation',
#  21860: 'HOUSEHOLD_1_189_CA_1_evaluation',
#  21870: 'HOUSEHOLD_1_190_CA_1_evaluation',
#  21880: 'HOUSEHOLD_1_191_CA_1_evaluation',
#  21890: 'HOUSEHOLD_1_192_CA_1_evaluation',
#  21900: 'HOUSEHOLD_1_193_CA_1_evaluation',
#  21910: 'HOUSEHOLD_1_194_CA_1_evaluation',
#  21920: 'HOUSEHOLD_1_195_CA_1_evaluation',
#  21930: 'HOUSEHOLD_1_196_CA_1_evaluation',
#  21940: 'HOUSEHOLD_1_197_CA_1_evaluation',
#  21950: 'HOUSEHOLD_1_198_CA_1_evaluation',
#  21960: 'HOUSEHOLD_1_199_CA_1_evaluation',
#  21970: 'HOUSEHOLD_1_200_CA_1_evaluation',
#  21980: 'HOUSEHOLD_1_201_CA_1_evaluation',
#  21990: 'HOUSEHOLD_1_202_CA_1_evaluation',
#  22000: 'HOUSEHOLD_1_203_CA_1_evaluation',
#  22010: 'HOUSEHOLD_1_204_CA_1_evaluation',
#  22020: 'HOUSEHOLD_1_205_CA_1_evaluation',
#  22030: 'HOUSEHOLD_1_206_CA_1_evaluation',
#  22040: 'HOUSEHOLD_1_207_CA_1_evaluation',
#  22050: 'HOUSEHOLD_1_208_CA_1_evaluation',
#  22060: 'HOUSEHOLD_1_209_CA_1_evaluation',
#  22070: 'HOUSEHOLD_1_210_CA_1_evaluation',
#  22080: 'HOUSEHOLD_1_211_CA_1_evaluation',
#  22090: 'HOUSEHOLD_1_212_CA_1_evaluation',
#  22100: 'HOUSEHOLD_1_213_CA_1_evaluation',
#  22110: 'HOUSEHOLD_1_214_CA_1_evaluation',
#  22120: 'HOUSEHOLD_1_215_CA_1_evaluation',
#  22130: 'HOUSEHOLD_1_216_CA_1_evaluation',
#  22140: 'HOUSEHOLD_1_217_CA_1_evaluation',
#  22150: 'HOUSEHOLD_1_218_CA_1_evaluation',
#  22160: 'HOUSEHOLD_1_219_CA_1_evaluation',
#  22170: 'HOUSEHOLD_1_220_CA_1_evaluation',
#  22180: 'HOUSEHOLD_1_221_CA_1_evaluation',
#  22190: 'HOUSEHOLD_1_222_CA_1_evaluation',
#  22200: 'HOUSEHOLD_1_223_CA_1_evaluation',
#  22210: 'HOUSEHOLD_1_224_CA_1_evaluation',
#  22220: 'HOUSEHOLD_1_225_CA_1_evaluation',
#  22230: 'HOUSEHOLD_1_226_CA_1_evaluation',
#  22240: 'HOUSEHOLD_1_227_CA_1_evaluation',
#  22250: 'HOUSEHOLD_1_228_CA_1_evaluation',
#  22260: 'HOUSEHOLD_1_229_CA_1_evaluation',
#  22270: 'HOUSEHOLD_1_230_CA_1_evaluation',
#  22280: 'HOUSEHOLD_1_231_CA_1_evaluation',
#  22290: 'HOUSEHOLD_1_232_CA_1_evaluation',
#  22300: 'HOUSEHOLD_1_233_CA_1_evaluation',
#  22310: 'HOUSEHOLD_1_234_CA_1_evaluation',
#  22320: 'HOUSEHOLD_1_235_CA_1_evaluation',
#  22330: 'HOUSEHOLD_1_236_CA_1_evaluation',
#  22340: 'HOUSEHOLD_1_237_CA_1_evaluation',
#  22350: 'HOUSEHOLD_1_238_CA_1_evaluation',
#  22360: 'HOUSEHOLD_1_239_CA_1_evaluation',
#  22370: 'HOUSEHOLD_1_241_CA_1_evaluation',
#  22380: 'HOUSEHOLD_1_242_CA_1_evaluation',
#  22390: 'HOUSEHOLD_1_243_CA_1_evaluation',
#  22400: 'HOUSEHOLD_1_244_CA_1_evaluation',
#  22410: 'HOUSEHOLD_1_245_CA_1_evaluation',
#  22420: 'HOUSEHOLD_1_246_CA_1_evaluation',
#  22430: 'HOUSEHOLD_1_247_CA_1_evaluation',
#  22440: 'HOUSEHOLD_1_248_CA_1_evaluation',
#  22450: 'HOUSEHOLD_1_249_CA_1_evaluation',
#  22460: 'HOUSEHOLD_1_250_CA_1_evaluation',
#  22470: 'HOUSEHOLD_1_251_CA_1_evaluation',
#  22480: 'HOUSEHOLD_1_252_CA_1_evaluation',
#  22490: 'HOUSEHOLD_1_253_CA_1_evaluation',
#  22500: 'HOUSEHOLD_1_254_CA_1_evaluation',
#  22510: 'HOUSEHOLD_1_255_CA_1_evaluation',
#  22520: 'HOUSEHOLD_1_256_CA_1_evaluation',
#  22530: 'HOUSEHOLD_1_257_CA_1_evaluation',
#  22540: 'HOUSEHOLD_1_258_CA_1_evaluation',
#  22550: 'HOUSEHOLD_1_259_CA_1_evaluation',
#  22560: 'HOUSEHOLD_1_260_CA_1_evaluation',
#  22570: 'HOUSEHOLD_1_261_CA_1_evaluation',
#  22580: 'HOUSEHOLD_1_262_CA_1_evaluation',
#  22590: 'HOUSEHOLD_1_263_CA_1_evaluation',
#  22600: 'HOUSEHOLD_1_264_CA_1_evaluation',
#  22610: 'HOUSEHOLD_1_265_CA_1_evaluation',
#  22620: 'HOUSEHOLD_1_266_CA_1_evaluation',
#  22630: 'HOUSEHOLD_1_267_CA_1_evaluation',
#  22640: 'HOUSEHOLD_1_268_CA_1_evaluation',
#  22650: 'HOUSEHOLD_1_269_CA_1_evaluation',
#  22660: 'HOUSEHOLD_1_270_CA_1_evaluation',
#  22670: 'HOUSEHOLD_1_271_CA_1_evaluation',
#  22680: 'HOUSEHOLD_1_272_CA_1_evaluation',
#  22690: 'HOUSEHOLD_1_274_CA_1_evaluation',
#  22700: 'HOUSEHOLD_1_275_CA_1_evaluation',
#  22710: 'HOUSEHOLD_1_276_CA_1_evaluation',
#  22720: 'HOUSEHOLD_1_277_CA_1_evaluation',
#  22730: 'HOUSEHOLD_1_278_CA_1_evaluation',
#  22740: 'HOUSEHOLD_1_279_CA_1_evaluation',
#  22750: 'HOUSEHOLD_1_280_CA_1_evaluation',
#  22760: 'HOUSEHOLD_1_281_CA_1_evaluation',
#  22770: 'HOUSEHOLD_1_282_CA_1_evaluation',
#  22780: 'HOUSEHOLD_1_283_CA_1_evaluation',
#  22790: 'HOUSEHOLD_1_284_CA_1_evaluation',
#  22800: 'HOUSEHOLD_1_285_CA_1_evaluation',
#  22810: 'HOUSEHOLD_1_286_CA_1_evaluation',
#  22820: 'HOUSEHOLD_1_287_CA_1_evaluation',
#  22830: 'HOUSEHOLD_1_288_CA_1_evaluation',
#  22840: 'HOUSEHOLD_1_289_CA_1_evaluation',
#  22850: 'HOUSEHOLD_1_290_CA_1_evaluation',
#  22860: 'HOUSEHOLD_1_291_CA_1_evaluation',
#  22870: 'HOUSEHOLD_1_292_CA_1_evaluation',
#  22880: 'HOUSEHOLD_1_293_CA_1_evaluation',
#  22890: 'HOUSEHOLD_1_294_CA_1_evaluation',
#  22900: 'HOUSEHOLD_1_295_CA_1_evaluation',
#  22910: 'HOUSEHOLD_1_296_CA_1_evaluation',
#  22920: 'HOUSEHOLD_1_297_CA_1_evaluation',
#  22930: 'HOUSEHOLD_1_298_CA_1_evaluation',
#  22940: 'HOUSEHOLD_1_299_CA_1_evaluation',
#  22950: 'HOUSEHOLD_1_300_CA_1_evaluation',
#  22960: 'HOUSEHOLD_1_301_CA_1_evaluation',
#  22970: 'HOUSEHOLD_1_302_CA_1_evaluation',
#  22980: 'HOUSEHOLD_1_303_CA_1_evaluation',
#  22990: 'HOUSEHOLD_1_304_CA_1_evaluation',
#  23000: 'HOUSEHOLD_1_305_CA_1_evaluation',
#  23010: 'HOUSEHOLD_1_306_CA_1_evaluation',
#  23020: 'HOUSEHOLD_1_307_CA_1_evaluation',
#  23030: 'HOUSEHOLD_1_308_CA_1_evaluation',
#  23040: 'HOUSEHOLD_1_309_CA_1_evaluation',
#  23050: 'HOUSEHOLD_1_310_CA_1_evaluation',
#  23060: 'HOUSEHOLD_1_311_CA_1_evaluation',
#  23070: 'HOUSEHOLD_1_312_CA_1_evaluation',
#  23080: 'HOUSEHOLD_1_313_CA_1_evaluation',
#  23090: 'HOUSEHOLD_1_314_CA_1_evaluation',
#  23100: 'HOUSEHOLD_1_315_CA_1_evaluation',
#  23110: 'HOUSEHOLD_1_316_CA_1_evaluation',
#  23120: 'HOUSEHOLD_1_317_CA_1_evaluation',
#  23130: 'HOUSEHOLD_1_318_CA_1_evaluation',
#  23140: 'HOUSEHOLD_1_319_CA_1_evaluation',
#  23150: 'HOUSEHOLD_1_320_CA_1_evaluation',
#  23160: 'HOUSEHOLD_1_321_CA_1_evaluation',
#  23170: 'HOUSEHOLD_1_322_CA_1_evaluation',
#  23180: 'HOUSEHOLD_1_323_CA_1_evaluation',
#  23190: 'HOUSEHOLD_1_324_CA_1_evaluation',
#  23200: 'HOUSEHOLD_1_325_CA_1_evaluation',
#  23210: 'HOUSEHOLD_1_326_CA_1_evaluation',
#  23220: 'HOUSEHOLD_1_327_CA_1_evaluation',
#  23230: 'HOUSEHOLD_1_328_CA_1_evaluation',
#  23240: 'HOUSEHOLD_1_329_CA_1_evaluation',
#  23250: 'HOUSEHOLD_1_330_CA_1_evaluation',
#  23260: 'HOUSEHOLD_1_331_CA_1_evaluation',
#  23270: 'HOUSEHOLD_1_332_CA_1_evaluation',
#  23280: 'HOUSEHOLD_1_333_CA_1_evaluation',
#  23290: 'HOUSEHOLD_1_334_CA_1_evaluation',
#  23300: 'HOUSEHOLD_1_335_CA_1_evaluation',
#  23310: 'HOUSEHOLD_1_336_CA_1_evaluation',
#  23320: 'HOUSEHOLD_1_337_CA_1_evaluation',
#  23330: 'HOUSEHOLD_1_338_CA_1_evaluation',
#  23340: 'HOUSEHOLD_1_339_CA_1_evaluation',
#  23350: 'HOUSEHOLD_1_340_CA_1_evaluation',
#  23360: 'HOUSEHOLD_1_341_CA_1_evaluation',
#  23370: 'HOUSEHOLD_1_342_CA_1_evaluation',
#  23380: 'HOUSEHOLD_1_343_CA_1_evaluation',
#  23390: 'HOUSEHOLD_1_344_CA_1_evaluation',
#  23400: 'HOUSEHOLD_1_345_CA_1_evaluation',
#  23410: 'HOUSEHOLD_1_346_CA_1_evaluation',
#  23420: 'HOUSEHOLD_1_347_CA_1_evaluation',
#  23430: 'HOUSEHOLD_1_348_CA_1_evaluation',
#  23440: 'HOUSEHOLD_1_349_CA_1_evaluation',
#  23450: 'HOUSEHOLD_1_350_CA_1_evaluation',
#  23460: 'HOUSEHOLD_1_351_CA_1_evaluation',
#  23470: 'HOUSEHOLD_1_353_CA_1_evaluation',
#  23480: 'HOUSEHOLD_1_354_CA_1_evaluation',
#  23490: 'HOUSEHOLD_1_355_CA_1_evaluation',
#  23500: 'HOUSEHOLD_1_356_CA_1_evaluation',
#  23510: 'HOUSEHOLD_1_357_CA_1_evaluation',
#  23520: 'HOUSEHOLD_1_358_CA_1_evaluation',
#  23530: 'HOUSEHOLD_1_359_CA_1_evaluation',
#  23540: 'HOUSEHOLD_1_360_CA_1_evaluation',
#  23550: 'HOUSEHOLD_1_361_CA_1_evaluation',
#  23560: 'HOUSEHOLD_1_362_CA_1_evaluation',
#  23570: 'HOUSEHOLD_1_363_CA_1_evaluation',
#  23580: 'HOUSEHOLD_1_364_CA_1_evaluation',
#  23590: 'HOUSEHOLD_1_365_CA_1_evaluation',
#  23600: 'HOUSEHOLD_1_366_CA_1_evaluation',
#  23610: 'HOUSEHOLD_1_367_CA_1_evaluation',
#  23620: 'HOUSEHOLD_1_368_CA_1_evaluation',
#  23630: 'HOUSEHOLD_1_369_CA_1_evaluation',
#  23640: 'HOUSEHOLD_1_370_CA_1_evaluation',
#  23650: 'HOUSEHOLD_1_371_CA_1_evaluation',
#  23660: 'HOUSEHOLD_1_372_CA_1_evaluation',
#  23670: 'HOUSEHOLD_1_373_CA_1_evaluation',
#  23680: 'HOUSEHOLD_1_374_CA_1_evaluation',
#  23690: 'HOUSEHOLD_1_375_CA_1_evaluation',
#  23700: 'HOUSEHOLD_1_376_CA_1_evaluation',
#  23710: 'HOUSEHOLD_1_377_CA_1_evaluation',
#  23720: 'HOUSEHOLD_1_378_CA_1_evaluation',
#  23730: 'HOUSEHOLD_1_379_CA_1_evaluation',
#  23740: 'HOUSEHOLD_1_380_CA_1_evaluation',
#  23750: 'HOUSEHOLD_1_381_CA_1_evaluation',
#  23760: 'HOUSEHOLD_1_382_CA_1_evaluation',
#  23770: 'HOUSEHOLD_1_383_CA_1_evaluation',
#  23780: 'HOUSEHOLD_1_384_CA_1_evaluation',
#  23790: 'HOUSEHOLD_1_385_CA_1_evaluation',
#  23800: 'HOUSEHOLD_1_386_CA_1_evaluation',
#  23810: 'HOUSEHOLD_1_387_CA_1_evaluation',
#  23820: 'HOUSEHOLD_1_388_CA_1_evaluation',
#  23830: 'HOUSEHOLD_1_389_CA_1_evaluation',
#  23840: 'HOUSEHOLD_1_390_CA_1_evaluation',
#  23850: 'HOUSEHOLD_1_393_CA_1_evaluation',
#  23860: 'HOUSEHOLD_1_394_CA_1_evaluation',
#  23870: 'HOUSEHOLD_1_395_CA_1_evaluation',
#  23880: 'HOUSEHOLD_1_396_CA_1_evaluation',
#  23890: 'HOUSEHOLD_1_397_CA_1_evaluation',
#  23900: 'HOUSEHOLD_1_398_CA_1_evaluation',
#  23910: 'HOUSEHOLD_1_399_CA_1_evaluation',
#  23920: 'HOUSEHOLD_1_400_CA_1_evaluation',
#  23930: 'HOUSEHOLD_1_401_CA_1_evaluation',
#  23940: 'HOUSEHOLD_1_402_CA_1_evaluation',
#  23950: 'HOUSEHOLD_1_403_CA_1_evaluation',
#  23960: 'HOUSEHOLD_1_404_CA_1_evaluation',
#  23970: 'HOUSEHOLD_1_405_CA_1_evaluation',
#  23980: 'HOUSEHOLD_1_406_CA_1_evaluation',
#  23990: 'HOUSEHOLD_1_407_CA_1_evaluation',
#  24000: 'HOUSEHOLD_1_408_CA_1_evaluation',
#  24010: 'HOUSEHOLD_1_409_CA_1_evaluation',
#  24020: 'HOUSEHOLD_1_410_CA_1_evaluation',
#  24030: 'HOUSEHOLD_1_411_CA_1_evaluation',
#  24040: 'HOUSEHOLD_1_412_CA_1_evaluation',
#  24050: 'HOUSEHOLD_1_413_CA_1_evaluation',
#  24060: 'HOUSEHOLD_1_414_CA_1_evaluation',
#  24070: 'HOUSEHOLD_1_415_CA_1_evaluation',
#  24080: 'HOUSEHOLD_1_416_CA_1_evaluation',
#  24090: 'HOUSEHOLD_1_417_CA_1_evaluation',
#  24100: 'HOUSEHOLD_1_418_CA_1_evaluation',
#  24110: 'HOUSEHOLD_1_419_CA_1_evaluation',
#  24120: 'HOUSEHOLD_1_420_CA_1_evaluation',
#  24130: 'HOUSEHOLD_1_421_CA_1_evaluation',
#  24140: 'HOUSEHOLD_1_422_CA_1_evaluation',
#  24150: 'HOUSEHOLD_1_423_CA_1_evaluation',
#  24160: 'HOUSEHOLD_1_424_CA_1_evaluation',
#  24170: 'HOUSEHOLD_1_425_CA_1_evaluation',
#  24180: 'HOUSEHOLD_1_426_CA_1_evaluation',
#  24190: 'HOUSEHOLD_1_427_CA_1_evaluation',
#  24200: 'HOUSEHOLD_1_428_CA_1_evaluation',
#  24210: 'HOUSEHOLD_1_429_CA_1_evaluation',
#  24220: 'HOUSEHOLD_1_430_CA_1_evaluation',
#  24230: 'HOUSEHOLD_1_431_CA_1_evaluation',
#  24240: 'HOUSEHOLD_1_432_CA_1_evaluation',
#  24250: 'HOUSEHOLD_1_433_CA_1_evaluation',
#  24260: 'HOUSEHOLD_1_434_CA_1_evaluation',
#  24270: 'HOUSEHOLD_1_435_CA_1_evaluation',
#  24280: 'HOUSEHOLD_1_436_CA_1_evaluation',
#  24290: 'HOUSEHOLD_1_437_CA_1_evaluation',
#  24300: 'HOUSEHOLD_1_438_CA_1_evaluation',
#  24310: 'HOUSEHOLD_1_439_CA_1_evaluation',
#  24320: 'HOUSEHOLD_1_440_CA_1_evaluation',
#  24330: 'HOUSEHOLD_1_441_CA_1_evaluation',
#  24340: 'HOUSEHOLD_1_442_CA_1_evaluation',
#  24350: 'HOUSEHOLD_1_443_CA_1_evaluation',
#  24360: 'HOUSEHOLD_1_444_CA_1_evaluation',
#  ...}

# %%
df
# Out:
#              id  item_id  dept_id  cat_id  store_id  state_id     d  sold  \
# 0         14370     1437        3       1         0         0     1     0
# 1         14380     1438        3       1         0         0     1     0
# 2         14390     1439        3       1         0         0     1     0
# 3         14400     1440        3       1         0         0     1     0
# 4         14410     1441        3       1         0         0     1     0
# ...         ...      ...      ...     ...       ...       ...   ...   ...
# 60034805  14329     1432        2       0         9         2  1969     0
# 60034806  14339     1433        2       0         9         2  1969     0
# 60034807  14349     1434        2       0         9         2  1969     0
# 60034808  14359     1435        2       0         9         2  1969     0
# 60034809  14369     1436        2       0         9         2  1969     0
#
#           wday  month  year  event_name_1  event_type_1  sell_price  snap  \
# 0            1      1  2011            30             4        8.26     0
# 1            1      1  2011            30             4        3.97     0
# 2            1      1  2011            30             4        2.97     0
# 3            1      1  2011            30             4        4.64     0
# 4            1      1  2011            30             4        2.98     0
# ...        ...    ...   ...           ...           ...         ...   ...
# 60034805     2      6  2016            16             3        2.98     0
# 60034806     2      6  2016            16             3        2.48     0
# 60034807     2      6  2016            16             3        3.98     0
# 60034808     2      6  2016            16             3        1.28     0
# 60034809     2      6  2016            16             3        1.00     0
#
#           weekend
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 60034805        1
# 60034806        1
# 60034807        1
# 60034808        1
# 60034809        1
#
# [60034810 rows x 16 columns]

# %%
print("Mean Encoding")
df["state_mean"] = df.groupby("state_id")["sold"].transform("mean").astype(np.float16)
df["store_mean"] = df.groupby("store_id")["sold"].transform("mean").astype(np.float16)
df["cat_mean"] = df.groupby("cat_id")["sold"].transform("mean").astype(np.float16)
df["dept_mean"] = df.groupby("dept_id")["sold"].transform("mean").astype(np.float16)
df["state_cat_mean"] = df.groupby(["state_id", "cat_id"])["sold"].transform("mean").astype(np.float16)
df["state_dept_mean"] = df.groupby(["state_id", "dept_id"])["sold"].transform("mean").astype(np.float16)
df["store_cat_mean"] = df.groupby(["store_id", "cat_id"])["sold"].transform("mean").astype(np.float16)
df["store_cat_mean"] = df.groupby(["dept_id", "cat_id"])["sold"].transform("mean").astype(np.float16)
df["item_id_mean"] = df.groupby("item_id")["sold"].transform("mean").astype(np.float16)
df["item_state_mean"] = df.groupby(["item_id", "state_id"])["sold"].transform("mean").astype(np.float16)
df["item_store_mean"] = df.groupby(["item_id", "store_id"])["sold"].transform("mean").astype(np.float16)
# Out:
# Mean Encoding
# CPU times: total: 46.4 s
# Wall time: 46.9 s

# %%
lags = [29, 30, 31, 32, 33, 34, 35, 40, 55, 60, 65, 180]
for lag in lags:
    df['sold_lag_' + str(lag)] = df.groupby(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'])['sold'].shift(lag).astype(np.float16)
    
df = df[df['d']>max(lags)]

# %%
df.to_pickle('data.pkl')
del df, calendar, sell_prices, train_eva
gc.collect()
# Out:
# 48

# %%
# Build model GBM
def lightgbm_model(X_train, y_train, X_valid, y_valid):
    model = LGBMRegressor(
        n_estimators=1000,
        learning_rate=0.3,
        subsample=0.8,
        colsample_bytree=0.8,
        max_depth=8,
        num_leaves=224,
        min_child_weight=300
    )
        
    model.fit(X_train, y_train, 
          eval_set=[(X_train,y_train),(X_valid,y_valid)], 
          verbose=20, 
          early_stopping_rounds=20,
          eval_metric='rmse')
    
    return model

def xgboost_model(X_train, y_train, X_valid, y_valid):
    model = XGBRegressor(
        n_estimators=1000,
        learning_rate=0.3,
        subsample=0.8,
        colsample_bytree=0.8,
        max_depth=8,
        min_child_weight=300
    )

    model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_valid, y_valid)],
              verbose=20,
              early_stopping_rounds=20,
              eval_metric='rmse')

    return model

def catboost_model(X_train, y_train, X_valid, y_valid):
    
    model = CatBoostRegressor(
        iterations=1000,
        learning_rate=0.3,
        subsample=0.8,
        colsample_bylevel=0.8,
        depth=8,
        l2_leaf_reg=224,
        min_child_samples=300,
        eval_metric='RMSE'
    )
    
    model.fit(X_train, y_train, eval_set=[(X_train,y_train),(X_valid,y_valid)],
              verbose=20, early_stopping_rounds=20)
    
    return model

# %%
data = pd.read_pickle('data.pkl')
valid = data[(data['d']>=1914) & (data['d']<1942)][['id','d','sold']]
test = data[data['d']>=1942][['id','d','sold']]
# Out:
# CPU times: total: 6.39 s
# Wall time: 8.84 s

# %%
for i in range(10):
    df = data[data["store_id"] == i]    
    #Create train set
    X_train, y_train = df[df['d']<1914].drop('sold',axis=1), df[df['d']<1914]['sold']
    X_valid, y_valid = df[(df['d']>=1914) & (df['d']<1942)].drop('sold',axis=1), df[(df['d']>=1914) & (df['d']<1942)]['sold']
    X_test = df[df["d"] >= 1942].drop("sold", axis=1)
       
    # Create model
    print(f"Train model for store {i}")
    print("--------")
    
    model = lightgbm_model(X_train, y_train, X_valid, y_valid)
    #model = xgboost_model(X_train, y_train, X_valid, y_valid)
    #model = catboost_model(X_train, y_train, X_valid, y_valid)
    
    print("--------")
    print(f"Predicting for store {i}")    
    # Validation predict
    pred_val = model.predict(X_valid)
    valid.loc[X_valid.index, "sold"] = pred_val
    pred_eva = model.predict(X_test)
    test.loc[X_test.index, "sold"] = pred_eva   
    print("--------")
    
    print("Saving model and clear memories")  
    print("--------")
    filename = f'model_store_{i}.pkl'
    # Save model and Clear memmory
    joblib.dump(model, filename)
    del model, X_train, y_train, X_valid, y_valid, X_test
    gc.collect()
# Out:
# Train model for store 0
# --------
# [20]	training's rmse: 2.5037	training's l2: 6.2685	valid_1's rmse: 2.28464	valid_1's l2: 5.21958
# [40]	training's rmse: 2.47832	training's l2: 6.14207	valid_1's rmse: 2.28023	valid_1's l2: 5.19947
# [60]	training's rmse: 2.45256	training's l2: 6.01503	valid_1's rmse: 2.27801	valid_1's l2: 5.18935
# [80]	training's rmse: 2.42868	training's l2: 5.89847	valid_1's rmse: 2.27739	valid_1's l2: 5.18649
# --------
# Predicting for store 0
# --------
# Saving model and clear memories
# --------
# Train model for store 1
# --------
# [20]	training's rmse: 1.88205	training's l2: 3.54211	valid_1's rmse: 2.09767	valid_1's l2: 4.40021
# [40]	training's rmse: 1.86348	training's l2: 3.47257	valid_1's rmse: 2.09004	valid_1's l2: 4.36828
# [60]	training's rmse: 1.8472	training's l2: 3.41215	valid_1's rmse: 2.08884	valid_1's l2: 4.36327
# --------
# Predicting for store 1
# --------
# Saving model and clear memories
# --------
# Train model for store 2
# --------
# [20]	training's rmse: 3.5749	training's l2: 12.7799	valid_1's rmse: 2.81326	valid_1's l2: 7.91444
# [40]	training's rmse: 3.53593	training's l2: 12.5028	valid_1's rmse: 2.79953	valid_1's l2: 7.83739
# --------
# Predicting for store 2
# --------
# Saving model and clear memories
# --------
# Train model for store 3
# --------
# [20]	training's rmse: 1.43555	training's l2: 2.06081	valid_1's rmse: 1.46876	valid_1's l2: 2.15726
# [40]	training's rmse: 1.42518	training's l2: 2.03112	valid_1's rmse: 1.46248	valid_1's l2: 2.13884
# [60]	training's rmse: 1.41166	training's l2: 1.99279	valid_1's rmse: 1.46192	valid_1's l2: 2.1372
# --------
# Predicting for store 3
# --------
# Saving model and clear memories
# --------
# Train model for store 4
# --------
# [20]	training's rmse: 2.05928	training's l2: 4.24063	valid_1's rmse: 1.86172	valid_1's l2: 3.46601
# [40]	training's rmse: 2.04347	training's l2: 4.17577	valid_1's rmse: 1.85931	valid_1's l2: 3.45704
# [60]	training's rmse: 2.02391	training's l2: 4.09621	valid_1's rmse: 1.85706	valid_1's l2: 3.44865
# --------
# Predicting for store 4
# --------
# Saving model and clear memories
# --------
# Train model for store 5
# --------
# [20]	training's rmse: 2.48727	training's l2: 6.18652	valid_1's rmse: 1.99667	valid_1's l2: 3.98668
# --------
# Predicting for store 5
# --------
# Saving model and clear memories
# --------
# Train model for store 6
# --------
# [20]	training's rmse: 2.14832	training's l2: 4.61526	valid_1's rmse: 2.1266	valid_1's l2: 4.52244
# [40]	training's rmse: 2.12294	training's l2: 4.50686	valid_1's rmse: 2.12501	valid_1's l2: 4.51566
# [60]	training's rmse: 2.10166	training's l2: 4.41695	valid_1's rmse: 2.12034	valid_1's l2: 4.49586
# --------
# Predicting for store 6
# --------
# Saving model and clear memories
# --------
# Train model for store 7
# --------
# [20]	training's rmse: 1.62787	training's l2: 2.64996	valid_1's rmse: 1.75908	valid_1's l2: 3.09438
# [40]	training's rmse: 1.60833	training's l2: 2.58672	valid_1's rmse: 1.75387	valid_1's l2: 3.07606
# [60]	training's rmse: 1.59303	training's l2: 2.53773	valid_1's rmse: 1.7495	valid_1's l2: 3.06076
# --------
# Predicting for store 7
# --------
# Saving model and clear memories
# --------
# Train model for store 8
# --------
# [20]	training's rmse: 2.67238	training's l2: 7.14159	valid_1's rmse: 3.06768	valid_1's l2: 9.41067
# [40]	training's rmse: 2.62365	training's l2: 6.88356	valid_1's rmse: 3.06667	valid_1's l2: 9.40449
# --------
# Predicting for store 8
# --------
# Saving model and clear memories
# --------
# Train model for store 9
# --------
# [20]	training's rmse: 2.37537	training's l2: 5.64237	valid_1's rmse: 2.14526	valid_1's l2: 4.60212
# [40]	training's rmse: 2.34845	training's l2: 5.5152	valid_1's rmse: 2.13713	valid_1's l2: 4.56733
# [60]	training's rmse: 2.31895	training's l2: 5.37752	valid_1's rmse: 2.13559	valid_1's l2: 4.56075
# --------
# Predicting for store 9
# --------
# Saving model and clear memories
# --------
# CPU times: total: 28min 18s
# Wall time: 6min 7s

# %% [raw]
# df["id"] = df["id"].astype('category')
# d_id = dict(zip(df["id"].cat.codes, df["id"]))

# %%
sample_sub = sample_sub[["id"]]
f_col = [f"F{i}" for i in range(1,29)]
f_col.insert(0, "id")

valid["id"] = valid["id"].map(d_id)
valid = valid.pivot(index="id", columns="d", values="sold").reset_index()
valid["id"] = valid["id"].str.replace("evaluation", "validation")
out_val = pd.merge(left=sample_sub[:30490], right=valid, on="id")
out_val.columns=f_col

test["id"] = test["id"].map(d_id)
test = test.pivot(index="id", columns="d", values="sold").reset_index()
out_eva = pd.merge(left=sample_sub[30490:], right=test, on="id")
out_eva.columns=f_col

submit = pd.concat([out_val,out_eva], ignore_index=True)

# %%
submit
# Out:
#                                   id        F1        F2        F3        F4  \
# 0      HOBBIES_1_001_CA_1_validation  0.737821  0.739214  0.618026  0.409374
# 1      HOBBIES_1_002_CA_1_validation  0.517442  0.424342  0.376557  0.393484
# 2      HOBBIES_1_003_CA_1_validation  0.320508  0.241412  0.243882  0.195059
# 3      HOBBIES_1_004_CA_1_validation  2.847385  2.326052  1.831858  1.974244
# 4      HOBBIES_1_005_CA_1_validation  0.989660  0.992663  0.767647  0.839653
# ...                              ...       ...       ...       ...       ...
# 60975    FOODS_3_823_WI_3_evaluation  0.454512  0.398428  0.484861  0.401221
# 60976    FOODS_3_824_WI_3_evaluation  0.262162  0.335127  0.346927  0.366667
# 60977    FOODS_3_825_WI_3_evaluation  0.699650  0.612286  0.674204  0.680861
# 60978    FOODS_3_826_WI_3_evaluation  0.806676  0.836485  0.884026  0.757005
# 60979    FOODS_3_827_WI_3_evaluation  0.574353  0.569682  0.514233  0.691595
#
#              F5        F6        F7        F8        F9  ...       F19  \
# 0      0.434809  0.532401  0.574502  0.497058  0.357214  ...  0.417413
# 1      0.386226  0.553480  0.429200  0.281708  0.274687  ...  0.231656
# 2      0.349210  0.274401  0.285683  0.306655  0.217021  ...  0.401972
# 3      1.641929  3.278841  2.754822  1.665133  1.724348  ...  2.118709
# 4      1.272917  1.846241  1.705305  1.516027  0.939189  ...  1.175731
# ...         ...       ...       ...       ...       ...  ...       ...
# 60975  0.588730  0.772080  0.727178  0.367147  0.492920  ...  0.560108
# 60976  0.486194  0.604629  0.612523  0.326290  0.407069  ...  0.254110
# 60977  0.681592  0.839051  1.035743  0.730338  0.814191  ...  1.263550
# 60978  1.138567  0.950184  1.124641  0.679002  0.716324  ...  0.762616
# 60979  1.173511  0.734661  0.844020  0.716306  0.829667  ...  1.086043
#
#             F20       F21       F22       F23       F24       F25       F26  \
# 0      0.608392  1.077895  0.638572  0.524287  0.437897  0.480209  0.800919
# 1      0.331134  0.267663  0.208777  0.185031  0.242531  0.316669  0.340452
# 2      0.624455  0.556116  0.538986  0.462953  0.493915  0.536232  0.533927
# 3      2.957944  2.898130  2.259407  2.231498  1.805736  1.556374  2.072538
# 4      1.395733  1.425418  1.014876  0.846364  0.924748  0.948913  0.966665
# ...         ...       ...       ...       ...       ...       ...       ...
# 60975  0.634305  0.693847  0.642489  0.529810  0.601463  0.594540  0.617179
# 60976  0.266593  0.421255  0.258323  0.342986  0.242536  0.205839  0.368010
# 60977  1.120115  1.170344  1.091583  1.115687  0.860299  0.586508  0.698515
# 60978  1.116610  0.726812  0.624449  0.724952  0.898118  0.734016  0.992694
# 60979  0.973268  1.128632  0.820003  0.791642  1.363904  0.920988  1.252592
#
#             F27       F28
# 0      0.776963  0.694525
# 1      0.404177  0.375451
# 2      0.499093  0.399817
# 3      3.243581  3.874095
# 4      1.492678  1.440547
# ...         ...       ...
# 60975  0.618593  1.004693
# 60976  0.350904  0.430791
# 60977  0.913552  1.174625
# 60978  1.375784  0.947414
# 60979  1.450102  1.579167
#
# [60980 rows x 29 columns]
