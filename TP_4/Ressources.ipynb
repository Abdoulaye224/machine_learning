# %%
import requests # see https://fr.python-requests.org/en/latest/
from requests.auth import HTTPBasicAuth
import json # see https://docs.python.org/fr/3/library/json.html
import numpy as np
import pandas as pd

# %%
# Your api key
api_key = "1767f88c-6e71-4d1d-81e6-f6324c83b1e3"

# ESGF server url (Switch to prod for real evaluation)
server_url = 'https://esgf-server-staging.herokuapp.com'

# Service name (see https://esgf-server-staging.herokuapp.com/docs)
service_name = 'get_inference_data'

# Service parameters.
params = f"?api_key={api_key}"

# Request header.
headers = {
       'Accept': 'application/json',
       'Authorization' : f"Bearer {api_key}"
}

# Server response. You receive a sample ID (id) that you must send back when you submit your prediction for it !
# Note you cannot send a prediction twice for a same sample id.
response = requests.get(f"{server_url}/{service_name}{params}", headers=headers)

# Logs.
print(response.text)

# Assert valid answer (see https://developer.mozilla.org/fr/docs/Web/HTTP/Status/200)
assert response.status_code == 200
# Out:
# {"id":"aYOSeakAJomd5Wld","x":"{\"wconfid\":{\"0\":3,\"1\":3,\"2\":3,\"3\":3,\"4\":3,\"5\":3,\"6\":3,\"7\":3,\"8\":3,\"9\":3,\"10\":3,\"11\":3,\"12\":3,\"13\":3,\"14\":3,\"15\":3,\"16\":3,\"17\":3,\"18\":3,\"19\":3,\"20\":3,\"21\":3,\"22\":3,\"23\":3,\"24\":3,\"25\":3,\"26\":3,\"27\":3,\"28\":3,\"29\":3,\"30\":3,\"31\":3},\"pctid\":{\"0\":40,\"1\":40,\"2\":40,\"3\":40,\"4\":40,\"5\":40,\"6\":40,\"7\":40,\"8\":40,\"9\":40,\"10\":40,\"11\":40,\"12\":40,\"13\":40,\"14\":40,\"15\":40,\"16\":40,\"17\":40,\"18\":40,\"19\":40,\"20\":40,\"21\":40,\"22\":40,\"23\":40,\"24\":40,\"25\":40,\"26\":40,\"27\":40,\"28\":40,\"29\":40,\"30\":40,\"31\":40},\"x\":{\"0\":0.969,\"1\":0.988,\"2\":1.008,\"3\":0.957,\"4\":1.035,\"5\":1.027,\"6\":0.984,\"7\":0.957,\"8\":1.008,\"9\":0.988,\"10\":0.949,\"11\":1.008,\"12\":0.965,\"13\":0.992,\"14\":0.945,\"15\":0.961,\"16\":0.969,\"17\":1.0,\"18\":1.047,\"19\":0.973,\"20\":0.992,\"21\":0.969,\"22\":0.988,\"23\":0.988,\"24\":1.008,\"25\":0.984,\"26\":0.98,\"27\":1.004,\"28\":0.965,\"29\":0.992,\"30\":1.031,\"31\":1.012},\"y\":{\"0\":-0.066,\"1\":0.008,\"2\":-0.051,\"3\":-0.055,\"4\":-0.047,\"5\":0.059,\"6\":-0.066,\"7\":0.027,\"8\":-0.043,\"9\":-0.086,\"10\":0.047,\"11\":-0.02,\"12\":-0.094,\"13\":0.004,\"14\":0.031,\"15\":0.105,\"16\":0.07,\"17\":0.09,\"18\":0.078,\"19\":-0.012,\"20\":0.012,\"21\":-0.113,\"22\":-0.008,\"23\":0.039,\"24\":-0.086,\"25\":-0.016,\"26\":0.012,\"27\":0.008,\"28\":0.078,\"29\":0.059,\"30\":-0.004,\"31\":0.012},\"z\":{\"0\":-0.121,\"1\":-0.113,\"2\":-0.105,\"3\":-0.137,\"4\":-0.152,\"5\":-0.098,\"6\":-0.141,\"7\":-0.125,\"8\":-0.109,\"9\":-0.152,\"10\":-0.105,\"11\":-0.105,\"12\":-0.141,\"13\":-0.121,\"14\":-0.141,\"15\":-0.121,\"16\":-0.105,\"17\":-0.129,\"18\":-0.102,\"19\":-0.137,\"20\":-0.137,\"21\":-0.117,\"22\":-0.156,\"23\":-0.125,\"24\":-0.113,\"25\":-0.152,\"26\":-0.109,\"27\":-0.152,\"28\":-0.105,\"29\":-0.105,\"30\":-0.086,\"31\":-0.121}}","info":"2 samples (498 remaining)."}

# %%
# Server answer as json. Dictionary with keys 'id' and 'x'
json_answer = response.json()

# Example id
example_id = json_answer['id']

# Parse str answer as json object
json_answer = json.loads(json_answer['x'])

# Frame answer
pd_sample = pd.DataFrame(json_answer)

# Logs. You should have (32,5).
print("Sample ID='{}' has shape {}".format(example_id, pd_sample.shape))
# Out:
# Sample ID='aYOSeakAJomd5Wld' has shape (32, 5)

# %%
pd_sample
# Out:
#     wconfid  pctid      x      y      z
# 0         3     40  0.969 -0.066 -0.121
# 1         3     40  0.988  0.008 -0.113
# 2         3     40  1.008 -0.051 -0.105
# 3         3     40  0.957 -0.055 -0.137
# 4         3     40  1.035 -0.047 -0.152
# 5         3     40  1.027  0.059 -0.098
# 6         3     40  0.984 -0.066 -0.141
# 7         3     40  0.957  0.027 -0.125
# 8         3     40  1.008 -0.043 -0.109
# 9         3     40  0.988 -0.086 -0.152
# 10        3     40  0.949  0.047 -0.105
# 11        3     40  1.008 -0.020 -0.105
# 12        3     40  0.965 -0.094 -0.141
# 13        3     40  0.992  0.004 -0.121
# 14        3     40  0.945  0.031 -0.141
# 15        3     40  0.961  0.105 -0.121
# 16        3     40  0.969  0.070 -0.105
# 17        3     40  1.000  0.090 -0.129
# 18        3     40  1.047  0.078 -0.102
# 19        3     40  0.973 -0.012 -0.137
# 20        3     40  0.992  0.012 -0.137
# 21        3     40  0.969 -0.113 -0.117
# 22        3     40  0.988 -0.008 -0.156
# 23        3     40  0.988  0.039 -0.125
# 24        3     40  1.008 -0.086 -0.113
# 25        3     40  0.984 -0.016 -0.152
# 26        3     40  0.980  0.012 -0.109
# 27        3     40  1.004  0.008 -0.152
# 28        3     40  0.965  0.078 -0.105
# 29        3     40  0.992  0.059 -0.105
# 30        3     40  1.031 -0.004 -0.086
# 31        3     40  1.012  0.012 -0.121

# %%
# Example URL to submit your prediction for a given example id
https://esgf-server-staging.herokuapp.com/predict?api_key=api_key&example_id=cVDV60OcLOagPgDv&prediction=1.0854,1.4223,100

# Your receive an observation from timestep 0 to 31, you make a prediction for the x,y,z values at time 32 !
# Out:
#   File "<ipython-input-8-9a057b4e0bce>", line 2
#     https://esgf-server-staging.herokuapp.com/predict?api_key=api_key&example_id=cVDV60OcLOagPgDv&prediction=1.0854,1.4223,100
#           ^
# SyntaxError: invalid syntax

# %%
# https://esgf-server-staging.herokuapp.com/leaderboard
