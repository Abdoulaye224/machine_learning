# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from bs4 import BeautifulSoup

# %% [markdown]
# ### Load datasets

# %%
positif = pd.read_pickle(r'imdb_raw_pos.pickle')

negatif = pd.read_pickle(r'imdb_raw_neg.pickle')

# %%
pos = {'review': positif}

neg = {'review': negatif}

# %% [markdown]
# ### Create a dataFrame

# %%
# Creates pandas DataFrame.
df1 = pd.DataFrame(pos)
df1['comment'] = 1

# %%
df2 = pd.DataFrame(neg)
df2['comment'] = 0

# %%
data = pd.concat([df1, df2])
data.head()
# Out:
#                                               review  comment
# 0  I went and saw this movie last night after bei...        1
# 1  Actor turned director Bill Paxton follows up h...        1
# 2  As a recreational golfer with some knowledge o...        1
# 3  I saw this film in a sneak preview, and it is ...        1
# 4  Bill Paxton has taken the true story of the 19...        1

# %%
data = data.sample(frac=1).reset_index()

data = data.drop(['index'], axis=1)

# %%
data.head()
# Out:
#                                               review  comment
# 0  I wish Depardieu had been able to finish his b...        0
# 1  Yet another version of mother of all gangster ...        0
# 2  I heard about this series in 2001 which a frie...        1
# 3  "The Charge at Feather River" is a routine Wes...        1
# 4  Tempest is based on the classic Shakespearean ...        0

# %% [markdown]
# <H2 style='color: cadetblue'> data cleaning </H2>

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_between_square_brackets(text):
    return text.replace('\[[^]]*\]', '')

def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    return text

# %%
data['review']=data['review'].apply(denoise_text)

# %%
def remove_special_characters(text, remove_digits=True):
    return text.replace('[^a-zA-z0-9\s]', '')

# %%
data['review']=data['review'].apply(remove_special_characters)

# %%
data['review']
# Out:
# 0        I wish Depardieu had been able to finish his b...
# 1        Yet another version of mother of all gangster ...
# 2        I heard about this series in 2001 which a frie...
# 3        "The Charge at Feather River" is a routine Wes...
# 4        Tempest is based on the classic Shakespearean ...
#                                ...
# 24995    What about DJ Cash Money??? This film fails in...
# 24996    Leni Riefenstahl would be embarrassed by the d...
# 24997    If it wasn't for Colin Firth, the movie would ...
# 24998    First and foremost I would like to say, that b...
# 24999    This is certainly a good film, beautifully pho...
# Name: review, Length: 25000, dtype: object

# %% [markdown]
# ### split dataset with 30% of datasets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data.review,data.comment, test_size= 0.3)

# %%
print("X_train = " , X_train.shape)
print("X_test = " , X_test.shape)
print("Y_train = " , Y_train.shape)
print("Y_test = " , Y_test.shape)
# Out:
# X_train =  (17500,)
# X_test =  (7500,)
# Y_train =  (17500,)
# Y_test =  (7500,)

# %% [markdown]
# ### Vectorization

# %%
cv=CountVectorizer(stop_words='english', binary=False,ngram_range=(1,1))

# %%
cv_train_reviews=cv.fit_transform(X_train)

# %%
cv_test_reviews=cv.transform(X_test)

# %%
print('BOW_cv_train:',cv_train_reviews.shape)
# Out:
# BOW_cv_train: (17500, 64585)

# %%
print('BOW_cv_test:',cv_test_reviews.shape)
# Out:
# BOW_cv_test: (7500, 64585)

# %%
print(cv_train_reviews)
# Out:
#   (0, 31857)	1
#   (0, 32166)	1
#   (0, 54987)	1
#   (0, 381)	1
#   (0, 47186)	1
#   (0, 7729)	1
#   (0, 17051)	1
#   (0, 32084)	1
#   (0, 57780)	1
#   (0, 62684)	2
#   (0, 38142)	1
#   (0, 27456)	1
#   (0, 30671)	2
#   (0, 32707)	4
#   (0, 24888)	2
#   (0, 1435)	2
#   (0, 27589)	1
#   (0, 56021)	1
#   (0, 17459)	1
#   (0, 8880)	1
#   (0, 57759)	1
#   (0, 38179)	1
#   (0, 34122)	1
#   (0, 33608)	1
#   (0, 63477)	1
#   :	:
#   (17499, 20599)	1
#   (17499, 28850)	1
#   (17499, 39885)	1
#   (17499, 46589)	1
#   (17499, 39386)	1
#   (17499, 4237)	1
#   (17499, 45095)	1
#   (17499, 15543)	2
#   (17499, 2853)	1
#   (17499, 21092)	1
#   (17499, 5984)	1
#   (17499, 9734)	1
#   (17499, 12526)	1
#   (17499, 7185)	1
#   (17499, 62218)	2
#   (17499, 32381)	1
#   (17499, 45325)	1
#   (17499, 49301)	2
#   (17499, 45244)	1
#   (17499, 11898)	1
#   (17499, 53538)	1
#   (17499, 7937)	1
#   (17499, 34879)	1
#   (17499, 47891)	1
#   (17499, 49896)	1

# %% [markdown]
# ### Logistic regression model on test dataset

# %%
lr=LogisticRegression(max_iter=5000)

# %%
cv_train_reviews.shape
# Out:
# (17500, 64505)

# %%
Y_train.shape
# Out:
# (17500,)

# %%
lr_bow=lr.fit(cv_train_reviews,Y_train)

# %%
lr_bow.score(cv_train_reviews, Y_train)
# Out:
# 0.9988571428571429

# %%
lr_bow.score(cv_test_reviews, Y_test)
# Out:
# 0.8832

# %% [markdown]
# ### Predict

# %%
lr_bow_predict=lr.predict(cv_test_reviews)
print(lr_bow_predict)
# Out:
# [0 0 0 ... 1 1 1]

# %% [markdown]
# ### Accuracy of the model

# %%
lr_bow_score=accuracy_score(Y_test,lr_bow_predict)
print("lr_bow_score :",lr_bow_score)
# Out:
# lr_bow_score : 0.8832

# %% [markdown]
# ### The classification report

# %%
lr_bow_report=classification_report(Y_test,lr_bow_predict,target_names=['Positive','Negative'])
print(lr_bow_report)
# Out:
#               precision    recall  f1-score   support
#
#     Positive       0.89      0.88      0.88      3778
#     Negative       0.88      0.89      0.88      3722
#
#     accuracy                           0.88      7500
#    macro avg       0.88      0.88      0.88      7500
# weighted avg       0.88      0.88      0.88      7500

# %% [markdown]
# ### confusion matrix

# %%
cm_bow=confusion_matrix(Y_test,lr_bow_predict,labels=[1,0])
disp = ConfusionMatrixDisplay(confusion_matrix=cm_bow, display_labels=['Positif', 'Negatif'])
disp.plot()

# %% [markdown]
# ### Test

# %%
from collections import OrderedDict
import operator

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
vectorizer = CountVectorizer()
vectorizer.fit(data.review)
# Out:
# CountVectorizer()

# %%
sort_by_grade = operator.itemgetter(1)

# %%
test = vectorizer.vocabulary_

# %%
sorted_value_key_pairs = sorted(test.items(), key=sort_by_grade, reverse=True)

# %%
{k: v for v, k in sorted_value_key_pairs}
# Out:
# {75015: 'כרמון',
#  75014: 'יגאל',
#  75013: 'żmijewski',
#  75012: 'þór',
#  75011: 'þorleifsson',
#  75010: 'ýs',
#  75009: 'üzümcü',
#  75008: 'ünfaithful',
#  75007: 'ünel',
#  75006: 'überwoman',
#  75005: 'übermenschlich',
#  75004: 'übermensch',
#  75003: 'über',
#  75002: 'úber',
#  75001: 'özdemir',
#  75000: 'örnek',
#  74999: 'önsjön',
#  74998: 'óli',
#  74997: 'ïts',
#  74996: 'ïn',
#  74995: 'île',
#  74994: 'ís',
#  74993: 'être',
#  74992: 'étoile',
#  74991: 'étienne',
#  74990: 'était',
#  74989: 'époque',
#  74988: 'émigrés',
#  74987: 'émigré',
#  74986: 'éloge',
#  74985: 'élan',
#  74984: 'édith',
#  74983: 'écoffey',
#  74982: 'çetin',
#  74981: 'ça',
#  74980: 'æon',
#  74979: 'æbler',
#  74978: 'âge',
#  74977: 'ànd',
#  74976: 'ªsen',
#  74975: 'zübert',
#  74974: 'zázvorková',
#  74973: 'zzzzzzzzzzzzzzzzzz',
#  74972: 'zzzzzzzzzzzzz',
#  74971: 'zzzzzzzzzzzz',
#  74970: 'zzzzzzzzz',
#  74969: 'zzzzz',
#  74968: 'zzzzip',
#  74967: 'zzzz',
#  74966: 'zz',
#  74965: 'zylberstein',
#  74964: 'zwick',
#  74963: 'zweite',
#  74962: 'zwarts',
#  74961: 'zwart',
#  74960: 'zuucka',
#  74959: 'zutaut',
#  74958: 'zurlini',
#  74957: 'zurer',
#  74956: 'zuotian',
#  74955: 'zulu',
#  74954: 'zuleta',
#  74953: 'zuleikha',
#  74952: 'zuleika',
#  74951: 'zula',
#  74950: 'zukor',
#  74949: 'zugurt',
#  74948: 'zuger',
#  74947: 'zues',
#  74946: 'zudina',
#  74945: 'zuckert',
#  74944: 'zuckers',
#  74943: 'zucker',
#  74942: 'zucher',
#  74941: 'zuccon',
#  74940: 'zucco',
#  74939: 'zuber',
#  74938: 'zubeidaa',
#  74937: 'zu',
#  74936: 'zsrs',
#  74935: 'zsrr',
#  74934: 'zsigmond',
#  74933: 'zshornack',
#  74932: 'zozo',
#  74931: 'zow',
#  74930: 'zounds',
#  74929: 'zotoh',
#  74928: 'zosh',
#  74927: 'zosch',
#  74926: 'zorro',
#  74925: 'zorn',
#  74924: 'zorkin',
#  74923: 'zorina',
#  74922: 'zord',
#  74921: 'zorba',
#  74920: 'zora',
#  74919: 'zor',
#  74918: 'zoot',
#  74917: 'zoos',
#  74916: 'zooms',
#  74915: 'zooming',
#  74914: 'zoomed',
#  74913: 'zoom',
#  74912: 'zoology',
#  74911: 'zoologists',
#  74910: 'zoologist',
#  74909: 'zoological',
#  74908: 'zoolander',
#  74907: 'zoog',
#  74906: 'zoo',
#  74905: 'zontar',
#  74904: 'zonker',
#  74903: 'zonked',
#  74902: 'zoning',
#  74901: 'zones',
#  74900: 'zoned',
#  74899: 'zone_',
#  74898: 'zone',
#  74897: 'zonca',
#  74896: 'zonadvd',
#  74895: 'zombified',
#  74894: 'zombification',
#  74893: 'zombiez',
#  74892: 'zombietown',
#  74891: 'zombies',
#  74890: 'zombiekilla81',
#  74889: 'zombie',
#  74888: 'zombi',
#  74887: 'zoltan',
#  74886: 'zolt',
#  74885: 'zola',
#  74884: 'zohra',
#  74883: 'zohan',
#  74882: 'zoftig',
#  74881: 'zoeys',
#  74880: 'zoey101',
#  74879: 'zoey',
#  74878: 'zoe',
#  74877: 'zodiac',
#  74876: 'zo',
#  74875: 'znyyqhuzzah',
#  74874: 'znidarsic',
#  74873: 'zlotoff',
#  74872: 'zlatorog',
#  74871: 'zizek',
#  74870: 'ziyi',
#  74869: 'zivojinovic',
#  74868: 'ziva',
#  74867: 'zito',
#  74866: 'ziti',
#  74865: 'zither',
#  74864: 'zit',
#  74863: 'zissou',
#  74862: 'zis',
#  74861: 'zircon',
#  74860: 'zips',
#  74859: 'zippy',
#  74858: 'zippo',
#  74857: 'zipping',
#  74856: 'zipperface',
#  74855: 'zippered',
#  74854: 'zipper',
#  74853: 'zipped',
#  74852: 'zipmole',
#  74851: 'ziplock',
#  74850: 'ziploc',
#  74849: 'zipless',
#  74848: 'zip',
#  74847: 'zionism',
#  74846: 'zion',
#  74845: 'zinner',
#  74844: 'zinnemann',
#  74843: 'zinneman',
#  74842: 'zings',
#  74841: 'zingers',
#  74840: 'zinger',
#  74839: 'zing',
#  74838: 'zinfandel',
#  74837: 'zines',
#  74836: 'zineb',
#  74835: 'zindulka',
#  74834: 'zindagi',
#  74833: 'zinda',
#  74832: 'zinc',
#  74831: 'zimmet',
#  74830: 'zimmerman',
#  74829: 'zimmer',
#  74828: 'zimina',
#  74827: 'zimbalu',
#  74826: 'zimbalist',
#  74825: 'zimbabwe',
#  74824: 'zima',
#  74823: 'zillions',
#  74822: 'zillion',
#  74821: 'zilcho',
#  74820: 'zilch',
#  74819: 'zigzagged',
#  74818: 'zigzag',
#  74817: 'ziggy',
#  74816: 'zigged',
#  74815: 'ziga',
#  74814: 'zig',
#  74813: 'zielcke',
#  74812: 'ziehl',
#  74811: 'ziegler',
#  74810: 'ziegfield',
#  74809: 'ziegfeld',
#  74808: 'zieff',
#  74807: 'zidi',
#  74806: 'zia',
#  74805: 'zhuravli',
#  74804: 'zhukov',
#  74803: 'zhu',
#  74802: 'zhou',
#  74801: 'zhiwen',
#  74800: 'zhivago',
#  74799: 'zhi',
#  74798: 'zheng',
#  74797: 'zhen',
#  74796: 'zhdanov',
#  74795: 'zhao',
#  74794: 'zhang',
#  74793: 'zhan',
#  74792: 'zhaan',
#  74791: 'zey',
#  74790: 'zeus',
#  74789: 'zeugma',
#  74788: 'zetterqvist',
#  74787: 'zeta',
#  74786: 'zesty',
#  74785: 'zest',
#  74784: 'zeros',
#  74783: 'zeroes',
#  74782: 'zero',
#  74781: 'zerkalo',
#  74780: 'zeretzka',
#  74779: 'zerbe',
#  74778: 'zeppo',
#  74777: 'zepplin',
#  74776: 'zeppelin',
#  74775: 'zepp',
#  74774: 'zephyr',
#  74773: 'zepher',
#  74772: 'zep',
#  74771: 'zeoy101',
#  74770: 'zeoy',
#  74769: 'zeon',
#  74768: 'zentropa',
#  74767: 'zenon',
#  74766: 'zenobia',
#  74765: 'zenna',
#  74764: 'zenith',
#  74763: 'zeng',
#  74762: 'zena',
#  74761: 'zen',
#  74760: 'zemljic',
#  74759: 'zemekis',
#  74758: 'zemeckis',
#  74757: 'zemarel',
#  74756: 'zeman',
#  74755: 'zelwigger',
#  74754: 'zelwegger',
#  74753: 'zelweger',
#  74752: 'zelmo',
#  74751: 'zellwegger',
#  74750: 'zellweger',
#  74749: 'zelleweger',
#  74748: 'zellenblock',
#  74747: 'zelina',
#  74746: 'zelig',
#  74745: 'zeleweger',
#  74744: 'zelda',
#  74743: 'zeland',
#  74742: 'zekiria',
#  74741: 'zeki',
#  74740: 'zekeria',
#  74739: 'zeke',
#  74738: 'zeitgeist',
#  74737: 'zeit',
#  74736: 'zeiram',
#  74735: 'zehn',
#  74734: 'zegt',
#  74733: 'zegers',
#  74732: 'zeffrem',
#  74731: 'zeffirelli',
#  74730: 'zefferelli',
#  74729: 'zeff',
#  74728: 'zeferelli',
#  74727: 'zeenat',
#  74726: 'zeena',
#  74725: 'zeek',
#  74724: 'zedong',
#  74723: 'zed',
#  74722: 'zeca',
#  74721: 'zebrowski',
#  74720: 'zebras',
#  74719: 'zebra',
#  74718: 'zealously',
#  74717: 'zealous',
#  74716: 'zealots',
#  74715: 'zealotry',
#  74714: 'zealot',
#  74713: 'zealnd',
#  74712: 'zealander',
#  74711: 'zealand',
#  74710: 'zeal',
#  74709: 'ze',
#  74708: 'zdf',
#  74707: 'zdenek',
#  74706: 'zdena',
#  74705: 'zchaundi',
#  74704: 'zbz',
#  74703: 'zbigniew',
#  74702: 'zbignew',
#  74701: 'zbiegnew',
#  74700: 'zb2',
#  74699: 'zb1',
#  74698: 'zazvorkova',
#  74697: 'zazu',
#  74696: 'zaza',
#  74695: 'zayed',
#  74694: 'zay',
#  74693: 'zatoichi',
#  74692: 'zathura',
#  74691: 'zatch',
#  74690: 'zasu',
#  74689: 'zaslow',
#  74688: 'zasalamel',
#  74687: 'zarzo',
#  74686: 'zarkov',
#  74685: 'zarkorr',
#  74684: 'zariah',
#  74683: 'zarhin',
#  74682: 'zare',
#  74681: 'zardoz',
#  74680: 'zarathustra',
#  74679: 'zara',
#  74678: 'zar',
#  74677: 'zaps',
#  74676: 'zappy',
#  74675: 'zapping',
#  74674: 'zapped',
#  74673: 'zappacosta',
#  74672: 'zappa',
#  74671: 'zaphod',
#  74670: 'zapata',
#  74669: 'zap',
#  74668: 'zanzibar',
#  74667: 'zany',
#  74666: 'zanuck',
#  74665: 'zanti',
#  74664: 'zantara',
#  74663: 'zantai',
#  74662: 'zanny',
#  74661: 'zannuck',
#  74660: 'zankiku',
#  74659: 'zaniness',
#  74658: 'zanily',
#  74657: 'zanier',
#  74656: 'zanie',
#  74655: 'zangief',
#  74654: 'zanghief',
#  74653: 'zangenberg',
#  74652: 'zane',
#  74651: 'zandt',
#  74650: 'zandor',
#  74649: 'zanatos',
#  74648: 'zana',
#  74647: 'zan',
#  74646: 'zamora',
#  74645: 'zamfir',
#  74644: 'zameer',
#  74643: 'zambibwia',
#  74642: 'zambia',
#  74641: 'zalman',
#  74640: 'zaljko',
#  74639: 'zalinsky',
#  74638: 'zale',
#  74637: 'zaldy',
#  74636: 'zakkyo',
#  74635: 'zakk',
#  74634: 'zakir',
#  74633: 'zakhm',
#  74632: 'zakheim',
#  74631: 'zak',
#  74630: 'zaire',
#  74629: 'zaillian',
#  74628: 'zai',
#  74627: 'zahn',
#  74626: 'zagarino',
#  74625: 'zaga',
#  74624: 'zag',
#  74623: 'zafroomulax',
#  74622: 'zafoid',
#  74621: 'zafar',
#  74620: 'zack',
#  74619: 'zachary',
#  74618: 'zach',
#  74617: 'zac',
#  74616: 'zabriskie',
#  74615: 'zabka',
#  74614: 'zabel',
#  74613: 'zaara',
#  74612: 'za',
#  74611: 'yûutsu',
#  74610: 'yôichi',
#  74609: 'yzma',
#  74608: 'yyz',
#  74607: 'yvonne',
#  74606: 'yvette',
#  74605: 'yves',
#  74604: 'yvelines',
#  74603: 'yvan',
#  74602: 'yv',
#  74601: 'yuznas',
#  74600: 'yuzna',
#  74599: 'yuuutsu',
#  74598: 'yuutsu',
#  74597: 'yuuck',
#  74596: 'yutzes',
#  74595: 'yutz',
#  74594: 'yutaro',
#  74593: 'yutani',
#  74592: 'yusuf',
#  74591: 'yusoufzai',
#  74590: 'yuria',
#  74589: 'yuri',
#  74588: 'yurets777',
#  74587: 'yuppy',
#  74586: 'yuppies',
#  74585: 'yuppie',
#  74584: 'yupanqui',
#  74583: 'yup',
#  74582: 'yungmee',
#  74581: 'yung',
#  74580: 'yunfei',
#  74579: 'yun',
#  74578: 'yumor',
#  74577: 'yummy',
#  74576: 'yummo',
#  74575: 'yummmmmrodney',
#  74574: 'yumiko',
#  74573: 'yumi',
#  74572: 'yuma',
#  74571: 'yum',
#  74570: 'yuliya',
#  74569: 'yuletide',
#  74568: 'yul',
#  74567: 'yuks',
#  74566: 'yukon',
#  74565: 'yuko',
#  74564: 'yukio',
#  74563: 'yuki',
#  74562: 'yukari',
#  74561: 'yuka',
#  74560: 'yuk',
#  74559: 'yuji',
#  74558: 'yuichiro',
#  74557: 'yuichi',
#  74556: 'yugoslavian',
#  74555: 'yugoslavia',
#  74554: 'yugoslav',
#  74553: 'yuen',
#  74552: 'yue',
#  74551: 'yucky',
#  74550: 'yuckiest',
#  74549: 'yuck',
#  74548: 'yucca',
#  74547: 'yucatan',
#  74546: 'yubaba',
#  74545: 'yuan',
#  74544: 'yu',
#  74543: 'yrs',
#  74542: 'yrf',
#  74541: 'yr',
#  74540: 'yquem',
#  74539: 'yoy',
#  74538: 'yowza',
#  74537: 'yowling',
#  74536: 'yow',
#  74535: 'youve',
#  74534: 'youv',
#  74533: 'youtube',
#  74532: 'youths',
#  74531: 'youthis',
#  74530: 'youthful',
#  74529: 'youth',
#  74528: 'youssefi',
#  74527: 'youssef',
#  74526: 'youself',
#  74525: 'yousef',
#  74524: 'yous',
#  74523: 'yourtime',
#  74522: 'yourselves',
#  74521: 'yourself',
#  74520: 'yours',
#  74519: 'yourhusband',
#  74518: 'yourelf',
#  74517: 'youre',
#  74516: 'your',
#  74515: 'youngstown',
#  74514: 'youngsters',
#  74513: 'youngster',
#  74512: 'youngson',
#  74511: 'youngs',
#  74510: 'youngman',
#  74509: 'youngish',
#  74508: 'youngins',
#  74507: 'youngest',
#  74506: 'youngers',
#  74505: 'younger',
#  74504: 'youngblood',
#  74503: 'youngaspiring',
#  74502: 'young',
#  74501: 'youg',
#  74500: 'youfor',
#  74499: 'youactually',
#  74498: 'you',
#  74497: 'yotoden',
#  74496: 'yothers',
#  74495: 'yossi',
#  74494: 'yosho',
#  74493: 'yoshiyuki',
#  74492: 'yoshitaru',
#  74491: 'yoshitaka',
#  74490: 'yoshinobu',
#  74489: 'yoshino',
#  74488: 'yoshimura',
#  74487: 'yoshimi',
#  74486: 'yoshiko',
#  74485: 'yoshikawa',
#  74484: 'yoshihiko',
#  74483: 'yoshida',
#  74482: 'yoshi',
#  74481: 'yosemite',
#  74480: 'yosemete',
#  74479: 'yosef',
#  74478: 'yorkshire',
#  74477: 'yorkers',
#  74476: 'yorker',
#  74475: 'york',
#  74474: 'yorga',
#  74473: 'yore',
#  74472: 'yorba',
#  74471: 'yoram',
#  74470: 'yor',
#  74469: 'yopgijogin',
#  74468: 'yootha',
#  74467: 'yoon',
#  74466: 'yoo',
#  74465: 'yonks',
#  74464: 'yoni',
#  74463: 'yong',
#  74462: 'yonder',
#  74461: 'yon',
#  74460: 'yomuri',
#  74459: 'yoman',
#  74458: 'yolngu',
#  74457: 'yolk',
#  74456: 'yolanda',
#  74455: 'yol',
#  74454: 'yokozuna',
#  74453: 'yokohama',
#  74452: 'yoko',
#  74451: 'yoknapatawpha',
#  74450: 'yokels',
#  74449: 'yokel',
#  74448: 'yoke',
#  74447: 'yojimbo',
#  74446: 'yoi',
#  74445: 'yohn',
#  74444: 'yogurt',
#  74443: 'yogi',
#  74442: 'yoganda',
#  74441: 'yoga',
#  74440: 'yodels',
#  74439: 'yodelling',
#  74438: 'yodeling',
#  74437: 'yodeler',
#  74436: 'yoda',
#  74435: 'yochi',
#  74434: 'yobs',
#  74433: 'yobbishness',
#  74432: 'yob',
#  74431: 'yo',
#  74430: 'yngwie',
#  74429: 'ymca',
#  74428: 'yma',
#  74427: 'yknow',
#  74426: 'yiu',
#  74425: 'yippy',
#  74424: 'yippies',
#  74423: 'yippie',
#  74422: 'yippeee',
#  74421: 'yippee',
#  74420: 'yipes',
#  74419: 'yipe',
#  74418: 'yip',
#  74417: 'yiong',
#  74416: 'yinsen',
#  74415: 'yings',
#  74414: 'ying',
#  74413: 'yin',
#  74412: 'yimou',
#  74411: 'yilmaz',
#  74410: 'yikes',
#  74409: 'yike',
#  74408: 'yigal',
#  74407: 'yields',
#  74406: 'yielding',
#  74405: 'yielded',
#  74404: 'yield',
#  74403: 'yiddish',
#  74402: 'yi',
#  74401: 'yevgeny',
#  74400: 'yeux',
#  74399: 'yeung',
#  74398: 'yet',
#  74397: 'yesteryear',
#  74396: 'yesterdays',
#  74395: 'yesterday',
#  74394: 'yester',
#  74393: 'yesilcam',
#  74392: 'yes3',
#  74391: 'yes',
#  74390: 'yera',
#  74389: 'yer',
#  74388: 'yep',
#  74387: 'yeowza',
#  74386: 'yeong',
#  74385: 'yeon',
#  74384: 'yeoman',
#  74383: 'yeom',
#  74382: 'yeoh',
#  74381: 'yeobright',
#  74380: 'yentl',
#  74379: 'yennefer',
#  74378: 'yen',
#  74377: 'yemi',
#  74376: 'yemen',
#  74375: 'yeltsin',
#  74374: 'yelps',
#  74373: 'yelping',
#  74372: 'yells',
#  74371: 'yellows',
#  74370: 'yellowish',
#  74369: 'yellowcoats',
#  74368: 'yellowcoat',
#  74367: 'yellow',
#  74366: 'yelling',
#  74365: 'yeller',
#  74364: 'yelled',
#  74363: 'yell',
#  74362: 'yelchin',
#  74361: 'yeh',
#  74360: 'yegor',
#  74359: 'yeesh',
#  74358: 'yeeeecchh',
#  74357: 'yeeeeah',
#  74356: 'yeeee',
#  74355: 'yeeeaaah',
#  74354: 'yee',
#  74353: 'yeck',
#  74352: 'yechy',
#  74351: 'yechh',
#  74350: 'yech',
#  74349: 'yecch',
#  74348: 'yeats',
#  74347: 'yeastless',
#  74346: 'yeast',
#  74345: 'yeash',
#  74344: 'yearwood',
#  74343: 'yearsthank',
#  74342: 'yearsjones',
#  74341: 'years',
#  74340: 'yearold',
#  74339: 'yearns',
#  74338: 'yearnings',
#  74337: 'yearning',
#  74336: 'yearned',
#  74335: 'yearn',
#  74334: 'yearly',
#  74333: 'yearling',
#  74332: 'yearbook',
#  74331: 'year',
#  74330: 'yeap',
#  74329: 'yeanin',
#  74328: 'yeah',
#  74327: 'yeager',
#  74326: 'yeaahhh',
#  74325: 'yea',
#  74324: 'ye',
#  74323: 'ycsf',
#  74322: 'yaël',
#  74321: 'yayy',
#  74320: 'yayoi',
#  74319: 'yay',
#  74318: 'yawp',
#  74317: 'yawns',
#  74316: 'yawning',
#  74315: 'yawnfest',
#  74314: 'yawner',
#  74313: 'yawned',
#  74312: 'yawn',
#  74311: 'yawkuh',
#  74310: 'yawk',
#  74309: 'yates',
#  74308: 'yat',
#  74307: 'yasuzo',
#  74306: 'yasushi',
#  74305: 'yasuoka',
#  74304: 'yasuko',
#  74303: 'yasujiru',
#  74302: 'yasujiro',
#  74301: 'yasuhara',
#  74300: 'yasudo',
#  74299: 'yassum',
#  74298: 'yassir',
#  74297: 'yassine',
#  74296: 'yasser',
#  74295: 'yasmine',
#  74294: 'yasmin',
#  74293: 'yashpal',
#  74292: 'yashimo',
#  74291: 'yasha',
#  74290: 'yash',
#  74289: 'yaself',
#  74288: 'yasbeck',
#  74287: 'yas',
#  74286: 'yarrr',
#  74285: 'yarr',
#  74284: 'yarns',
#  74283: 'yarnek',
#  74282: 'yarn',
#  74281: 'yarmulke',
#  74280: 'yarmouth',
#  74279: 'yargh',
#  74278: 'yared',
#  74277: 'yardsticks',
#  74276: 'yardstick',
#  74275: 'yards',
#  74274: 'yardley',
#  74273: 'yardbirds',
#  74272: 'yard',
#  74271: 'yarbrough',
#  74270: 'yarborough',
#  74269: 'yar',
#  74268: 'yapping',
#  74267: 'yappers',
#  74266: 'yaphet',
#  74265: 'yap',
#  74264: 'yaoi',
#  74263: 'yanov',
#  74262: 'yanomano',
#  74261: 'yanomani',
#  74260: 'yanni',
#  74259: 'yanne',
#  74258: 'yann',
#  74257: 'yanks',
#  74256: 'yankovsky',
#  74255: 'yankovich',
#  74254: 'yanking',
#  74253: 'yankie',
#  74252: 'yankees',
#  74251: 'yankee',
#  74250: 'yanked',
#  74249: 'yank',
#  74248: 'yangtze',
#  74247: 'yangstze',
#  74246: 'yangon',
#  74245: 'yangchun',
#  74244: 'yang',
#  74243: 'yancy',
#  74242: 'yancey',
#  74241: 'yanachkov',
#  74240: 'yan',
#  74239: 'yammering',
#  74238: 'yammacraux',
#  74237: 'yamazaki',
#  74236: 'yamato',
#  74235: 'yamashta',
#  74234: 'yamaoka',
#  74233: 'yamaguchi',
#  74232: 'yamada',
#  74231: 'yamad',
#  74230: 'yamacraw',
#  74229: 'yama',
#  74228: 'yalta',
#  74227: 'yall',
#  74226: 'yale',
#  74225: 'yakuzza',
#  74224: 'yakuza',
#  74223: 'yakusho',
#  74222: 'yakking',
#  74221: 'yakkel',
#  74220: 'yakin',
#  74219: 'yakima',
#  74218: 'yak',
#  74217: 'yahweh',
#  74216: 'yahoos',
#  74215: 'yahoo',
#  74214: 'yah',
#  74213: 'yagyu',
#  74212: 'yagher',
#  74211: 'yaffa',
#  74210: 'yael',
#  74209: 'yadon',
#  74208: 'yadkinville',
#  74207: 'yaddayadda',
#  74206: 'yadda',
#  74205: 'yadayadayada',
#  74204: 'yadav',
#  74203: 'yada',
#  74202: 'yacking',
#  74201: 'yachtsmen',
#  74200: 'yachts',
#  74199: 'yachting',
#  74198: 'yacht',
#  74197: 'yabalans',
#  74196: 'yaawn',
#  74195: 'yaadein',
#  74194: 'yaaayyyy',
#  74193: 'yaaayy',
#  74192: 'ya',
#  74191: 'y2k',
#  74190: 'y12',
#  74189: 'xyz',
#  74188: 'xylophone',
#  74187: 'xygtho',
#  74186: 'xy',
#  74185: 'xxxxx',
#  74184: 'xxx',
#  74183: 'xxist',
#  74182: 'xxii',
#  74181: 'xx',
#  74180: 'xvid',
#  74179: 'xvi',
#  74178: 'xv',
#  74177: 'xuejian',
#  74176: 'xue',
#  74175: 'xtro',
#  74174: 'xtc',
#  74173: 'xpw',
#  74172: 'xptyngi',
#  74171: 'xperiment',
#  74170: 'xp',
#  74169: 'xoxo',
#  74168: 'xo',
#  74167: 'xmen',
#  74166: 'xmas',
#  74165: 'xm',
#  74164: 'xlr',
#  74163: 'xlibris',
#  74162: 'xl5',
#  74161: 'xl',
#  74160: 'xixth',
#  74159: 'xix',
#  74158: 'xiong',
#  74157: 'xin',
#  74156: 'ximenes',
#  74155: 'xii',
#  74154: 'xica',
#  74153: 'xiaofeng',
#  74152: 'xiao',
#  74151: 'xianghua',
#  74150: 'xian',
#  74149: 'xia',
#  74148: 'xi',
#  74147: 'xhosa',
#  74146: 'xers',
#  74145: 'xerox',
#  74144: 'xenophobic',
#  74143: 'xenophobia',
#  74142: 'xenophobes',
#  74141: 'xenophobe',
#  74140: 'xenia',
#  74139: 'xena',
#  74138: 'xe',
#  74137: 'xd',
#  74136: 'xbox360',
#  74135: 'xbox',
#  74134: 'xaviertalk',
#  74133: 'xavier',
#  74132: 'xaverl',
#  74131: 'xartan',
#  74130: 'xander',
#  74129: 'xanadu',
#  74128: 'x3',
#  74127: 'x2',
#  74126: 'x100',
#  74125: 'württemberg',
#  74124: 'wyoming',
#  74123: 'wynyard',
#  74122: 'wynorski',
#  74121: 'wynona',
#  74120: 'wynne',
#  74119: 'wynn',
#  74118: 'wyngarde',
#  74117: 'wyndham',
#  74116: 'wymark',
#  74115: 'wyman',
#  74114: 'wyler',
#  74113: 'wylde',
#  74112: 'wyden',
#  74111: 'wycherly',
#  74110: 'wyatt',
#  74109: 'wxyz',
#  74108: 'www2',
#  74107: 'www',
#  74106: 'wws',
#  74105: 'wwii',
#  74104: 'wwi',
#  74103: 'wwhyyyy',
#  74102: 'wwf',
#  74101: 'wwe',
#  74100: 'wwd',
#  74099: 'ww3',
#  74098: 'ww2',
#  74097: 'ww11',
#  74096: 'ww1',
#  74095: 'ww',
#  74094: 'wv',
#  74093: 'wuzzy',
#  74092: 'wuz',
#  74091: 'wuxia',
#  74090: 'wutt',
#  74089: 'wuthering',
#  74088: 'wussy',
#  74087: 'wusses',
#  74086: 'wuss',
#  74085: 'wurtzle',
#  74084: 'wurtzel',
#  74083: 'wup',
#  74082: 'wuneng',
#  74081: 'wunderkind',
#  74080: 'wullenweber',
#  74079: 'wulfsohn',
#  74078: 'wukong',
#  74077: 'wujing',
#  74076: 'wuhrer',
#  74075: 'wuhl',
#  74074: 'wuheva',
#  74073: 'wuher',
#  74072: 'wuhan',
#  74071: 'wuerzburg',
#  74070: 'wudy',
#  74069: 'wubc',
#  74068: 'wu',
#  74067: 'wttw',
#  74066: 'wtih',
#  74065: 'wth',
#  74064: 'wtg',
#  74063: 'wtf',
#  74062: 'wtc',
#  74061: 'wtbs',
#  74060: 'wsop',
#  74059: 'wsga',
#  74058: 'ws',
#  74057: 'wryly',
#  74056: 'wry',
#  74055: 'wrung',
#  74054: 'wrp24',
#  74053: 'wrought',
#  74052: 'wrote',
#  74051: 'wrongwith',
#  74050: 'wrongthis',
#  74049: 'wrongs',
#  74048: 'wrongness',
#  74047: 'wrongly',
#  74046: 'wrongheadedly',
#  74045: 'wrongfully',
#  74044: 'wrongful',
#  74043: 'wrongest',
#  74042: 'wronged',
#  74041: 'wrongdoings',
#  74040: 'wrongdoing',
#  74039: 'wrongdoers',
#  74038: 'wrongdoer',
#  74037: 'wrong',
#  74036: 'writting',
#  74035: 'writtern',
#  74034: 'written',
#  74033: 'writings',
#  74032: 'writing',
#  74031: 'writin',
#  74030: 'writhing',
#  74029: 'writhes',
#  74028: 'writhe',
#  74027: 'writes',
#  74026: 'writers',
#  74025: 'writerly',
#  74024: 'writer',
#  74023: 'write',
#  74022: 'writ',
#  74021: 'wristwatch',
#  74020: 'wrists',
#  74019: 'wristed',
#  74018: 'wristbands',
#  74017: 'wrist',
#  74016: 'wrinkly',
#  ...}

# %%
X_bag_of_words = vectorizer.transform(data.review)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 X_bag_of_words = vectorizer.transform(data.review)
#
# File ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1255, in CountVectorizer.transform(self, raw_documents)
#    1252 self._check_vocabulary()
#    1254 # use the same matrix-building strategy as fit_transform
# -> 1255 _, X = self._count_vocab(raw_documents, fixed_vocab=True)
#    1256 if self.binary:
#    1257     X.data.fill(1)
#
# File ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1115, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1113 for doc in raw_documents:
#    1114     feature_counter = {}
# -> 1115     for feature in analyze(doc):
#    1116         try:
#    1117             feature_idx = vocabulary[feature]
#
# File ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:111, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     109             doc = ngrams(doc, stop_words)
#     110         else:
# --> 111             doc = ngrams(doc)
#     112 return doc
#
# File ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:222, in _VectorizerMixin._word_ngrams(self, tokens, stop_words)
#     217         raise ValueError("np.nan is an invalid document, expected byte or "
#     218                          "unicode string.")
#     220     return doc
# --> 222 def _word_ngrams(self, tokens, stop_words=None):
#     223     """Turn tokens into a sequence of n-grams after stop words filtering"""
#     224     # handle stop words
#
# KeyboardInterrupt:

# %%
X_bag_of_words
# Out:
# <25000x75016 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3366100 stored elements in Compressed Sparse Row format>
